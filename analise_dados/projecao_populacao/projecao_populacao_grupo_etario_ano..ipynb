# %%
import polars as pl
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pl.read_parquet('projecao_populacao_2000_2070.parquet')

# %%
df.head()
# Out:
# shape: (5, 72)
# ┌──────────────┬──────────┬──────────┬──────────┬───┬─────────┬─────────┬─────────┬─────────┐
# │ grupo_etario ┆ 2000     ┆ 2001     ┆ 2002     ┆ … ┆ 2067    ┆ 2068    ┆ 2069    ┆ 2070    │
# │ ---          ┆ ---      ┆ ---      ┆ ---      ┆   ┆ ---     ┆ ---     ┆ ---     ┆ ---     │
# │ str          ┆ i64      ┆ i64      ┆ i64      ┆   ┆ i64     ┆ i64     ┆ i64     ┆ i64     │
# ╞══════════════╪══════════╪══════════╪══════════╪═══╪═════════╪═════════╪═════════╪═════════╡
# │  00-04       ┆ 17281547 ┆ 17123682 ┆ 16906493 ┆ … ┆ 7744772 ┆ 7673320 ┆ 7606268 ┆ 7543093 │
# │  05-09       ┆ 17378990 ┆ 17390172 ┆ 17379924 ┆ … ┆ 8168636 ┆ 8071186 ┆ 7979360 ┆ 7893433 │
# │  10-14       ┆ 17599378 ┆ 17471598 ┆ 17382310 ┆ … ┆ 8703349 ┆ 8591634 ┆ 8480688 ┆ 8371817 │
# │  15-19       ┆ 17831344 ┆ 17866394 ┆ 17852790 ┆ … ┆ 9236029 ┆ 9132638 ┆ 9026379 ┆ 8917283 │
# │  20-24       ┆ 16402228 ┆ 16826765 ┆ 17170628 ┆ … ┆ 9697332 ┆ 9606213 ┆ 9512994 ┆ 9417186 │
# ...

# %%
df_tidy = df.unpivot(
    index='grupo_etario',
    on=[str(x) for x in range(2000, 2071)],
    variable_name='ano',
    value_name='populacao'
).with_columns(
    pl.col('ano').cast(pl.Int64)
)

# %%
df_tidy.head()
# Out:
# shape: (5, 3)
# ┌──────────────┬──────┬───────────┐
# │ grupo_etario ┆ ano  ┆ populacao │
# │ ---          ┆ ---  ┆ ---       │
# │ str          ┆ i64  ┆ i64       │
# ╞══════════════╪══════╪═══════════╡
# │  00-04       ┆ 2000 ┆ 17281547  │
# │  05-09       ┆ 2000 ┆ 17378990  │
# │  10-14       ┆ 2000 ┆ 17599378  │
# │  15-19       ┆ 2000 ┆ 17831344  │
# │  20-24       ┆ 2000 ┆ 16402228  │
# └──────────────┴──────┴───────────┘

# %%
print(sorted(df_tidy.select(pl.col('grupo_etario')).unique().to_series().to_list()))
# Out:
# [' 00-04', ' 05-09', ' 10-14', ' 15-19', ' 20-24', ' 25-29', ' 30-34', ' 35-39', ' 40-44', ' 45-49', ' 50-54', ' 55-59', ' 60-64', ' 65-69', ' 70-74', ' 75-79', ' 80-84', ' 85-89', '90+']

# %%
df_jovem = df_tidy.filter(
    pl.col('grupo_etario').is_in([' 15-19', ' 20-24', ' 25-29'])
)

# %%
df_jovem.head()
# Out:
# shape: (5, 3)
# ┌──────────────┬──────┬───────────┐
# │ grupo_etario ┆ ano  ┆ populacao │
# │ ---          ┆ ---  ┆ ---       │
# │ str          ┆ i64  ┆ i64       │
# ╞══════════════╪══════╪═══════════╡
# │  15-19       ┆ 2000 ┆ 17831344  │
# │  20-24       ┆ 2000 ┆ 16402228  │
# │  25-29       ┆ 2000 ┆ 14351864  │
# │  15-19       ┆ 2001 ┆ 17866394  │
# │  20-24       ┆ 2001 ┆ 16826765  │
# └──────────────┴──────┴───────────┘

# %%
df_idoso = df_tidy.filter(
    pl.col('grupo_etario').is_in([
        ' 60-64', ' 65-69', ' 70-74', 
        ' 75-79', ' 80-84', ' 85-89', '90+'
    ])
)

# %%
df_idoso.head()
# Out:
# shape: (5, 3)
# ┌──────────────┬──────┬───────────┐
# │ grupo_etario ┆ ano  ┆ populacao │
# │ ---          ┆ ---  ┆ ---       │
# │ str          ┆ i64  ┆ i64       │
# ╞══════════════╪══════╪═══════════╡
# │  60-64       ┆ 2000 ┆ 4702598   │
# │  65-69       ┆ 2000 ┆ 3678357   │
# │  70-74       ┆ 2000 ┆ 2861050   │
# │  75-79       ┆ 2000 ┆ 1955661   │
# │  80-84       ┆ 2000 ┆ 1148811   │
# └──────────────┴──────┴───────────┘

# %%
sorted(df_idoso.select('grupo_etario').unique().to_series().to_list())
# Out:
# [' 60-64', ' 65-69', ' 70-74', ' 75-79', ' 80-84', ' 85-89', '90+']

# %%
df_idoso_6069 = df_idoso.filter(
    pl.col('grupo_etario').is_in([' 60-64', ' 65-69'])
).with_columns(
    pl.lit('60-69').alias('grupo_etario')
).group_by(['grupo_etario', 'ano']).agg(
    pl.col('populacao').sum()
)

# %%
df_idoso_6069.head()
# Out:
# shape: (5, 3)
# ┌──────────────┬──────┬───────────┐
# │ grupo_etario ┆ ano  ┆ populacao │
# │ ---          ┆ ---  ┆ ---       │
# │ str          ┆ i64  ┆ i64       │
# ╞══════════════╪══════╪═══════════╡
# │ 60-69        ┆ 2027 ┆ 20347388  │
# │ 60-69        ┆ 2038 ┆ 24489576  │
# │ 60-69        ┆ 2029 ┆ 21166094  │
# │ 60-69        ┆ 2037 ┆ 23966599  │
# │ 60-69        ┆ 2043 ┆ 27502965  │
# └──────────────┴──────┴───────────┘

# %%
df_idoso_7079 = df_idoso.filter(
    pl.col('grupo_etario').is_in([' 70-74', ' 75-79'])
).with_columns(
    pl.lit('70-79').alias('grupo_etario')
).group_by(['grupo_etario', 'ano']).agg(
    pl.col('populacao').sum()
)

# %%
df_idoso_7079.head()
# Out:
# shape: (5, 3)
# ┌──────────────┬──────┬───────────┐
# │ grupo_etario ┆ ano  ┆ populacao │
# │ ---          ┆ ---  ┆ ---       │
# │ str          ┆ i64  ┆ i64       │
# ╞══════════════╪══════╪═══════════╡
# │ 70-79        ┆ 2052 ┆ 23026778  │
# │ 70-79        ┆ 2004 ┆ 5372935   │
# │ 70-79        ┆ 2058 ┆ 25318410  │
# │ 70-79        ┆ 2067 ┆ 25241900  │
# │ 70-79        ┆ 2045 ┆ 19476343  │
# └──────────────┴──────┴───────────┘

# %%
df_idoso_8090 = df_idoso.filter(
    pl.col('grupo_etario').is_in([' 80-84', ' 85-89', '90+'])
).with_columns(
    pl.lit('80-90+').alias('grupo_etario')
).group_by(['grupo_etario', 'ano']).agg(
    pl.col('populacao').sum()
)

# %%
df_idoso_8090.head()
# Out:
# shape: (5, 3)
# ┌──────────────┬──────┬───────────┐
# │ grupo_etario ┆ ano  ┆ populacao │
# │ ---          ┆ ---  ┆ ---       │
# │ str          ┆ i64  ┆ i64       │
# ╞══════════════╪══════╪═══════════╡
# │ 80-90+       ┆ 2028 ┆ 5688584   │
# │ 80-90+       ┆ 2067 ┆ 21936242  │
# │ 80-90+       ┆ 2058 ┆ 17582138  │
# │ 80-90+       ┆ 2030 ┆ 6259435   │
# │ 80-90+       ┆ 2042 ┆ 10922339  │
# └──────────────┴──────┴───────────┘

# %%
df_concated = pl.concat([
    df_jovem,
    df_idoso_6069,
    df_idoso_7079,
    df_idoso_8090
], how='vertical')

# %%
df_concated
# Out:
# shape: (426, 3)
# ┌──────────────┬──────┬───────────┐
# │ grupo_etario ┆ ano  ┆ populacao │
# │ ---          ┆ ---  ┆ ---       │
# │ str          ┆ i64  ┆ i64       │
# ╞══════════════╪══════╪═══════════╡
# │  15-19       ┆ 2000 ┆ 17831344  │
# │  20-24       ┆ 2000 ┆ 16402228  │
# │  25-29       ┆ 2000 ┆ 14351864  │
# │  15-19       ┆ 2001 ┆ 17866394  │
# │  20-24       ┆ 2001 ┆ 16826765  │
# │ …            ┆ …    ┆ …         │
# │ 80-90+       ┆ 2053 ┆ 15437488  │
# │ 80-90+       ┆ 2059 ┆ 18114185  │
# │ 80-90+       ┆ 2038 ┆ 9170052   │
# │ 80-90+       ┆ 2016 ┆ 3694903   │
# │ 80-90+       ┆ 2000 ┆ 2032255   │
# └──────────────┴──────┴───────────┘

# %%
df_pd = df_concated.to_pandas()

# %%
anos = sorted(df_concated.select('ano').unique().to_series().to_list())

# %%
fig, ax = plt.subplots(figsize=(14, 8))

sns.lineplot(
    df_pd,
    x='ano',
    y='populacao',
    hue='grupo_etario',
    ax=ax,
    palette='Dark2'
)

ax.tick_params('x', rotation=90)
ax.set_xticks(anos)
ax.legend(loc="upper left", bbox_to_anchor=(1, 1), title="Grupo Etário")
ax.set_ylabel('População projetada')
ax.set_xlabel('Ano')
ax.grid()
ax.set_facecolor('lightgray')

plt.tight_layout()
fig.savefig('projecao_populacao_grupo_etario_ano.png', dpi=300, bbox_inches='tight')
plt.show()
