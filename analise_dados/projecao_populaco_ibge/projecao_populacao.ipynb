# %%
import polars as pl
import matplotlib.pyplot as plt

# %% [markdown]
# # ANÁLISE INICIAL

# %%
pl.Config.set_tbl_cols(-1)
pl.Config.set_tbl_rows(-1)
# Out:
# polars.config.Config

# %%
url = 'projecoes_2024_tab1_idade_simples.ods'

# %%
df = pl.read_ods(url)

# %%
df.head()
# Out:
# shape: (5, 76)
# ┌─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┐
# │ IDA ┆ SEX ┆ CÓD ┆ SIG ┆ LOC ┆ 200 ┆ 200 ┆ 200 ┆ 200 ┆ 200 ┆ 200 ┆ 200 ┆ 200 ┆ 200 ┆ 200 ┆ 201 ┆ 201 ┆ 201 ┆ 201 ┆ 201 ┆ 201 ┆ 201 ┆ 201 ┆ 201 ┆ 201 ┆ 202 ┆ 202 ┆ 202 ┆ 202 ┆ 202 ┆ 202 ┆ 202 ┆ 202 ┆ 202 ┆ 202 ┆ 203 ┆ 203 ┆ 203 ┆ 203 ┆ 203 ┆ 203 ┆ 203 ┆ 203 ┆ 203 ┆ 203 ┆ 204 ┆ 204 ┆ 204 ┆ 204 ┆ 204 ┆ 204 ┆ 204 ┆ 204 ┆ 204 ┆ 204 ┆ 205 ┆ 205 ┆ 205 ┆ 205 ┆ 205 ┆ 205 ┆ 205 ┆ 205 ┆ 205 ┆ 205 ┆ 206 ┆ 206 ┆ 206 ┆ 206 ┆ 206 ┆ 206 ┆ 206 ┆ 206 ┆ 206 ┆ 206 ┆ 207 │
# ...

# %%
df = df.filter(
    pl.col('LOCAL') == 'Brasil'
).drop([
    'SIGLA', 
    'LOCAL',
    'CÓD.'
]).rename({
    'IDADE': 'idade',
    'SEXO': 'sexo'
})

# %%
df.head()
# Out:
# shape: (5, 73)
# ┌─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┐
# │ ida ┆ sex ┆ 200 ┆ 200 ┆ 200 ┆ 200 ┆ 200 ┆ 200 ┆ 200 ┆ 200 ┆ 200 ┆ 200 ┆ 201 ┆ 201 ┆ 201 ┆ 201 ┆ 201 ┆ 201 ┆ 201 ┆ 201 ┆ 201 ┆ 201 ┆ 202 ┆ 202 ┆ 202 ┆ 202 ┆ 202 ┆ 202 ┆ 202 ┆ 202 ┆ 202 ┆ 202 ┆ 203 ┆ 203 ┆ 203 ┆ 203 ┆ 203 ┆ 203 ┆ 203 ┆ 203 ┆ 203 ┆ 203 ┆ 204 ┆ 204 ┆ 204 ┆ 204 ┆ 204 ┆ 204 ┆ 204 ┆ 204 ┆ 204 ┆ 204 ┆ 205 ┆ 205 ┆ 205 ┆ 205 ┆ 205 ┆ 205 ┆ 205 ┆ 205 ┆ 205 ┆ 205 ┆ 206 ┆ 206 ┆ 206 ┆ 206 ┆ 206 ┆ 206 ┆ 206 ┆ 206 ┆ 206 ┆ 206 ┆ 207 │
# ...

# %%
df_unpivoted =  df.unpivot(
    index=['idade', 'sexo'],
    on=[str(x) for x in range(2000, 2071)],
    variable_name='ano',
    value_name='populacao_projetada'
).with_columns(
    pl.col('idade').cast(pl.Int8),
    pl.col('sexo').cast(pl.Categorical),
    pl.col('ano').cast(pl.Int16),
    pl.col('populacao_projetada').cast(pl.Float32),
)

# %%
df_unpivoted.head()
# Out:
# shape: (5, 4)
# ┌───────┬───────┬──────┬─────────────────────┐
# │ idade ┆ sexo  ┆ ano  ┆ populacao_projetada │
# │ ---   ┆ ---   ┆ ---  ┆ ---                 │
# │ i8    ┆ cat   ┆ i16  ┆ f32                 │
# ╞═══════╪═══════╪══════╪═════════════════════╡
# │ 0     ┆ Ambos ┆ 2000 ┆ 3.423475e6          │
# │ 1     ┆ Ambos ┆ 2000 ┆ 3.450022e6          │
# │ 2     ┆ Ambos ┆ 2000 ┆ 3.461038e6          │
# │ 3     ┆ Ambos ┆ 2000 ┆ 3.469109e6          │
# │ 4     ┆ Ambos ┆ 2000 ┆ 3.477903e6          │
# └───────┴───────┴──────┴─────────────────────┘

# %% [markdown]
# # ANÁLISE POR ANO E SEXO

# %%
df_ano_sexo = df_unpivoted.group_by(['ano', 'sexo']).agg(
    pl.col('populacao_projetada').sum()
).sort('ano', descending=False)

# %%
df_ano_sexo.head()
# Out:
# shape: (5, 3)
# ┌──────┬──────────┬─────────────────────┐
# │ ano  ┆ sexo     ┆ populacao_projetada │
# │ ---  ┆ ---      ┆ ---                 │
# │ i16  ┆ cat      ┆ f32                 │
# ╞══════╪══════════╪═════════════════════╡
# │ 2000 ┆ Ambos    ┆ 1.74695872e8        │
# │ 2000 ┆ Mulheres ┆ 8.897524e7          │
# │ 2000 ┆ Homens   ┆ 8.5720712e7         │
# │ 2001 ┆ Ambos    ┆ 1.77003712e8        │
# │ 2001 ┆ Homens   ┆ 8.6821416e7         │
# └──────┴──────────┴─────────────────────┘

# %%
populacao_h_max = df_ano_sexo.filter(
    pl.col('sexo') ==  'Homens'
).sort(
    'populacao_projetada', 
    descending=True
).row(0)[0]

# %%
populacao_m_max = df_ano_sexo.filter(
    pl.col('sexo') ==  'Mulheres'
).sort(
    'populacao_projetada', 
    descending=True
).row(0)[0]

# %%
populacao_max = df_ano_sexo.filter(
    pl.col('sexo') ==  'Ambos'
).sort(
    'populacao_projetada', 
    descending=True
).row(0)[0]

# %%
fig, ax = plt.subplots(figsize=(15, 10))

marcadores = ['o', '>', 'd']
anos = sorted(df_ano_sexo.select('ano').unique().to_series().to_list())

for (sexo, grupo), marcador in zip(df_ano_sexo.group_by('sexo'), marcadores):
    ax.plot(
        grupo.select('ano').to_series(), 
        grupo.select('populacao_projetada').to_series(),
        label=sexo,
        marker=marcador
    )

ax.legend(title='Sexo', loc='upper left', bbox_to_anchor=(1, 1))
ax.grid()
ax.tick_params('x',  rotation=90)
ax.set_xticks(anos)
ax.set_ylabel('População Projetada')
ax.set_xlabel('Ano')
ax.axvline(2041, color='red', linestyle='--')
ax.axvline(2042, color='red', linestyle='-')

plt.figtext(0.5, -0.03, 
            """Nota: A linha tracejada (2041) indica o pico populacioanl da população brasileira e dos homens.\n Nota: A linha contínua (2042) indica o pico populacional das mulheres.""", 
            ha='center', 
            fontsize=10, 
            style='italic'
)
plt.tight_layout()
fig.savefig('projecao_populacao_ano_sexo.png', dpi=300, bbox_inches='tight')
plt.show()

# %% [markdown]
# # ANÁLISE POR ANO, SEXO E GRUPO ETÁRIO

# %%
df_unpivoted.head()
# Out:
# shape: (5, 4)
# ┌───────┬───────┬──────┬─────────────────────┐
# │ idade ┆ sexo  ┆ ano  ┆ populacao_projetada │
# │ ---   ┆ ---   ┆ ---  ┆ ---                 │
# │ i8    ┆ cat   ┆ i16  ┆ f32                 │
# ╞═══════╪═══════╪══════╪═════════════════════╡
# │ 0     ┆ Ambos ┆ 2000 ┆ 3.423475e6          │
# │ 1     ┆ Ambos ┆ 2000 ┆ 3.450022e6          │
# │ 2     ┆ Ambos ┆ 2000 ┆ 3.461038e6          │
# │ 3     ┆ Ambos ┆ 2000 ┆ 3.469109e6          │
# │ 4     ┆ Ambos ┆ 2000 ┆ 3.477903e6          │
# └───────┴───────┴──────┴─────────────────────┘

# %%
df_menor = df_unpivoted.filter(
    pl.col('idade').is_in(range(0, 18))
).with_columns(
    pl.lit('0-17').alias('grupo_etario')
).drop('idade')

# %%
df_menor.head()
# Out:
# shape: (5, 4)
# ┌───────┬──────┬─────────────────────┬──────────────┐
# │ sexo  ┆ ano  ┆ populacao_projetada ┆ grupo_etario │
# │ ---   ┆ ---  ┆ ---                 ┆ ---          │
# │ cat   ┆ i16  ┆ f32                 ┆ str          │
# ╞═══════╪══════╪═════════════════════╪══════════════╡
# │ Ambos ┆ 2000 ┆ 3.423475e6          ┆ 0-17         │
# │ Ambos ┆ 2000 ┆ 3.450022e6          ┆ 0-17         │
# │ Ambos ┆ 2000 ┆ 3.461038e6          ┆ 0-17         │
# │ Ambos ┆ 2000 ┆ 3.469109e6          ┆ 0-17         │
# │ Ambos ┆ 2000 ┆ 3.477903e6          ┆ 0-17         │
# └───────┴──────┴─────────────────────┴──────────────┘

# %%
df_jovem_adulto = df_unpivoted.filter(
    pl.col('idade').is_in(range(18, 30))
).with_columns(
    pl.lit('18-29').alias('grupo_etario')
).drop('idade')

# %%
df_jovem_adulto.head()
# Out:
# shape: (5, 4)
# ┌───────┬──────┬─────────────────────┬──────────────┐
# │ sexo  ┆ ano  ┆ populacao_projetada ┆ grupo_etario │
# │ ---   ┆ ---  ┆ ---                 ┆ ---          │
# │ cat   ┆ i16  ┆ f32                 ┆ str          │
# ╞═══════╪══════╪═════════════════════╪══════════════╡
# │ Ambos ┆ 2000 ┆ 3.550835e6          ┆ 18-29        │
# │ Ambos ┆ 2000 ┆ 3.524484e6          ┆ 18-29        │
# │ Ambos ┆ 2000 ┆ 3.473651e6          ┆ 18-29        │
# │ Ambos ┆ 2000 ┆ 3.392522e6          ┆ 18-29        │
# │ Ambos ┆ 2000 ┆ 3.289954e6          ┆ 18-29        │
# └───────┴──────┴─────────────────────┴──────────────┘

# %%
df_adulto = df_unpivoted.filter(
    pl.col('idade').is_in(range(30, 59))
).with_columns(
    pl.lit('30-59').alias('grupo_etario')
).drop('idade')

# %%
df_adulto.head()
# Out:
# shape: (5, 4)
# ┌───────┬──────┬─────────────────────┬──────────────┐
# │ sexo  ┆ ano  ┆ populacao_projetada ┆ grupo_etario │
# │ ---   ┆ ---  ┆ ---                 ┆ ---          │
# │ cat   ┆ i16  ┆ f32                 ┆ str          │
# ╞═══════╪══════╪═════════════════════╪══════════════╡
# │ Ambos ┆ 2000 ┆ 2.737933e6          ┆ 30-59        │
# │ Ambos ┆ 2000 ┆ 2.707517e6          ┆ 30-59        │
# │ Ambos ┆ 2000 ┆ 2.681825e6          ┆ 30-59        │
# │ Ambos ┆ 2000 ┆ 2.659697e6          ┆ 30-59        │
# │ Ambos ┆ 2000 ┆ 2.635267e6          ┆ 30-59        │
# └───────┴──────┴─────────────────────┴──────────────┘

# %%
df_unpivoted.select('idade').max()
# Out:
# shape: (1, 1)
# ┌───────┐
# │ idade │
# │ ---   │
# │ i8    │
# ╞═══════╡
# │ 90    │
# └───────┘

# %%
df_idoso = df_unpivoted.filter(
    pl.col('idade').is_in(range(60, 90))
).with_columns(
    pl.lit('60-90+').alias('grupo_etario')
).drop('idade')

# %%
df_idoso.head()
# Out:
# shape: (5, 4)
# ┌───────┬──────┬─────────────────────┬──────────────┐
# │ sexo  ┆ ano  ┆ populacao_projetada ┆ grupo_etario │
# │ ---   ┆ ---  ┆ ---                 ┆ ---          │
# │ cat   ┆ i16  ┆ f32                 ┆ str          │
# ╞═══════╪══════╪═════════════════════╪══════════════╡
# │ Ambos ┆ 2000 ┆ 1.012572e6          ┆ 60-90+       │
# │ Ambos ┆ 2000 ┆ 980936.0            ┆ 60-90+       │
# │ Ambos ┆ 2000 ┆ 945680.0            ┆ 60-90+       │
# │ Ambos ┆ 2000 ┆ 904355.0            ┆ 60-90+       │
# │ Ambos ┆ 2000 ┆ 859055.0            ┆ 60-90+       │
# └───────┴──────┴─────────────────────┴──────────────┘

# %%
df_concat = pl.concat(
    [df_menor, df_jovem_adulto, df_adulto, df_idoso],
    how='vertical'
).with_columns(
    pl.col('grupo_etario').cast(pl.Categorical)
)

# %%
df_concat.head()
# Out:
# shape: (5, 4)
# ┌───────┬──────┬─────────────────────┬──────────────┐
# │ sexo  ┆ ano  ┆ populacao_projetada ┆ grupo_etario │
# │ ---   ┆ ---  ┆ ---                 ┆ ---          │
# │ cat   ┆ i16  ┆ f32                 ┆ cat          │
# ╞═══════╪══════╪═════════════════════╪══════════════╡
# │ Ambos ┆ 2000 ┆ 3.423475e6          ┆ 0-17         │
# │ Ambos ┆ 2000 ┆ 3.450022e6          ┆ 0-17         │
# │ Ambos ┆ 2000 ┆ 3.461038e6          ┆ 0-17         │
# │ Ambos ┆ 2000 ┆ 3.469109e6          ┆ 0-17         │
# │ Ambos ┆ 2000 ┆ 3.477903e6          ┆ 0-17         │
# └───────┴──────┴─────────────────────┴──────────────┘

# %%
df_ano_ge = df_concat.filter(
    pl.col('sexo') == 'Ambos'
).group_by(['ano', 'grupo_etario']).agg(
    pl.col('populacao_projetada').sum()
).with_columns(
    pl.col('grupo_etario').cast(pl.Categorical)
).sort(['ano', 'grupo_etario'], descending=False)

# %%
df_ano_ge.head()
# Out:
# shape: (5, 3)
# ┌──────┬──────────────┬─────────────────────┐
# │ ano  ┆ grupo_etario ┆ populacao_projetada │
# │ ---  ┆ ---          ┆ ---                 │
# │ i16  ┆ cat          ┆ f32                 │
# ╞══════╪══════════════╪═════════════════════╡
# │ 2000 ┆ 0-17         ┆ 6.3015944e7         │
# │ 2000 ┆ 18-29        ┆ 3.7829412e7         │
# │ 2000 ┆ 30-59        ┆ 5.75777e7           │
# │ 2000 ┆ 60-90+       ┆ 1.4925615e7         │
# │ 2001 ┆ 0-17         ┆ 6.2739804e7         │
# └──────┴──────────────┴─────────────────────┘

# %%
fig, ax = plt.subplots(figsize=(15, 10))

marcadores = ['o', '>', 'd', 's']

for (ge, grupo), marcador in zip(df_ano_ge.group_by('grupo_etario'), marcadores):
    plt.plot(
        grupo.select('ano'),
        grupo.select('populacao_projetada'),
        label=ge,
        marker=marcador
    )

ax.tick_params('x', rotation=90)
ax.set_xticks(anos)
ax.grid()
ax.legend(title='Grupo Etário', loc='upper left', bbox_to_anchor=(1, 1))
ax.set_ylabel('População Projetada')
ax.set_xlabel('Ano')

plt.tight_layout()
fig.savefig('projecao_populacao_ano_grupo_etario.png', dpi=300, bbox_inches='tight')
plt.show()

# %% [markdown]
# # ANÁLISE POR ANO, SEXO E GRUPO ETÁRIO

# %%
df_concat.head()

# %%
df_ano_sexo_ge = df_concat.filter(
    pl.col('sexo') != 'Ambos'
).group_by(['sexo', 'ano', 'grupo_etario']).agg(
    pl.col('populacao_projetada').sum()
)

# %%
df_ano_sexo_ge.head()

# %%
df_ano_sexo_ge_h = df_ano_sexo_ge.filter(
    pl.col('sexo') == 'Homens'
).sort(['ano', 'grupo_etario'], descending=False)

# %%
df_ano_sexo_ge_h.select('sexo').unique()

# %%
df_ano_sexo_ge_m = df_ano_sexo_ge.filter(
    pl.col('sexo') == 'Mulheres'
).sort(['ano', 'grupo_etario'], descending=False)

# %%
df_ano_sexo_ge_m.select('sexo').unique()

# %%
fig, ax = plt.subplots(figsize=(15, 10))

marcadores = ['o', '>', 'd', 's']

for (ge, grupo), marcador in zip(df_ano_sexo_ge_h.group_by('grupo_etario'), marcadores):
    plt.plot(
        grupo.select('ano'),
        grupo.select('populacao_projetada'),
        label=ge,
        marker=marcador
    )
ax.grid()
ax.legend(title='Grupos Etários', loc='upper left', bbox_to_anchor=(1, 1))
ax.tick_params('x', rotation=90)
ax.set_xticks(anos)
ax.set_ylabel('População Projetada')
ax.set_xlabel('Ano')

plt.tight_layout()
fig.savefig('projecao_populacao_ano_grupo_etario_homens.png', dpi=300, bbox_inches='tight')
plt.show()

# %%
fig, ax = plt.subplots(figsize=(15, 10))

marcadores = ['o', '>', 'd', 's']

for (ge, grupo), marcador in zip(df_ano_sexo_ge_h.group_by('grupo_etario'), marcadores):
    plt.plot(
        grupo.select('ano'),
        grupo.select('populacao_projetada'),
        label=ge,
        marker=marcador
    )
ax.grid()
ax.legend(title='Grupos Etários', loc='upper left', bbox_to_anchor=(1, 1))
ax.tick_params('x', rotation=90)
ax.set_xticks(anos)
ax.set_ylabel('População Projetada')
ax.set_xlabel('Ano')

plt.tight_layout()
fig.savefig('projecao_populacao_ano_grupo_etario_mulheres.png', dpi=300, bbox_inches='tight')
plt.show()
