# %%
import polars as pl

# %%
df = pl.read_parquet('population_male_18yo.parquet')

# %%
df.head()
# Out:
# shape: (5, 2)
# ┌──────┬──────────────────────┐
# │ year ┆ predicted_population │
# │ ---  ┆ ---                  │
# │ i16  ┆ f32                  │
# ╞══════╪══════════════════════╡
# │ 2000 ┆ 1.765864e6           │
# │ 2001 ┆ 1.775253e6           │
# │ 2002 ┆ 1.783828e6           │
# │ 2003 ┆ 1.784804e6           │
# │ 2004 ┆ 1.77741e6            │
# └──────┴──────────────────────┘
