# %%
import polars as pl
import geopandas as gpd
import matplotlib.pyplot as plt
import matplotlib.ticker as ticker

# %%
pl.Config.set_tbl_cols(-1)
pl.Config.set_tbl_rows(-1)
# Out:
# polars.config.Config

# %% [markdown]
# # ETL & DATA WANGLING

# %%
df_etl = pl.scan_parquet('dados_parquet/*/*.parquet').collect()

# %%
df_etl.head()
# Out:
# shape: (5, 15)
# ┌─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬────────┬───────┬───────┬───────┐
# │ ANO ┆ PES ┆ ALT ┆ MUN ┆ UF_ ┆ PAI ┆ EST ┆ SEX ┆ ESC ┆ VIN ┆ DIS ┆ ZONA_R ┆ MUN_R ┆ UF_RE ┆ PAIS_ │
# │ _NA ┆ O   ┆ URA ┆ _NA ┆ NAS ┆ S_N ┆ ADO ┆ O   ┆ OLA ┆ CUL ┆ PEN ┆ ESIDEN ┆ ESIDE ┆ SIDEN ┆ RESID │
# │ SCI ┆ --- ┆ --- ┆ SCI ┆ CIM ┆ ASC ┆ _CI ┆ --- ┆ RID ┆ ACA ┆ SA  ┆ CIAL   ┆ NCIA  ┆ CIA   ┆ ENCIA │
# │ MEN ┆ str ┆ str ┆ MEN ┆ ENT ┆ IME ┆ VIL ┆ str ┆ ADE ┆ O_A ┆ --- ┆ ---    ┆ ---   ┆ ---   ┆ ---   │
# │ TO  ┆     ┆     ┆ TO  ┆ O   ┆ NTO ┆ --- ┆     ┆ --- ┆ NO  ┆ str ┆ str    ┆ str   ┆ str   ┆ str   │
# │ --- ┆     ┆     ┆ --- ┆ --- ┆ --- ┆ str ┆     ┆ str ┆ --- ┆     ┆        ┆       ┆       ┆       │
# │ str ┆     ┆     ┆ str ┆ str ┆ str ┆     ┆     ┆     ┆ str ┆     ┆        ┆       ┆       ┆       │
# ╞═════╪═════╪═════╪═════╪═════╪═════╪═════╪═════╪═════╪═════╪═════╪════════╪═══════╪═══════╪═══════╡
# │ 198 ┆ 95  ┆ 181 ┆ DES ┆ SP  ┆ BRA ┆ Sol ┆ M   ┆ Ens ┆ 200 ┆ Sem ┆ Urbana ┆ PIRAS ┆ SP    ┆ BRASI │
# │ 9   ┆     ┆     ┆ CAL ┆     ┆ SIL ┆ tei ┆     ┆ ino ┆ 7   ┆ dis ┆        ┆ SUNUN ┆       ┆ L     │
# │     ┆     ┆     ┆ VAD ┆     ┆     ┆ ro  ┆     ┆ Méd ┆     ┆ pen ┆        ┆ GA    ┆       ┆       │
# │     ┆     ┆     ┆ O   ┆     ┆     ┆     ┆     ┆ io  ┆     ┆ sa  ┆        ┆       ┆       ┆       │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ Com ┆     ┆     ┆        ┆       ┆       ┆       │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ ple ┆     ┆     ┆        ┆       ┆       ┆       │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ to  ┆     ┆     ┆        ┆       ┆       ┆       │
# │ 198 ┆ 64  ┆ 173 ┆ CAT ┆ SP  ┆ BRA ┆ Cas ┆ M   ┆ Ens ┆ 200 ┆ Sem ┆ Urbana ┆ SAO   ┆ SP    ┆ BRASI │
# │ 9   ┆     ┆     ┆ AND ┆     ┆ SIL ┆ ado ┆     ┆ ino ┆ 7   ┆ dis ┆        ┆ PAULO ┆       ┆ L     │
# │     ┆     ┆     ┆ UVA ┆     ┆     ┆     ┆     ┆ Sup ┆     ┆ pen ┆        ┆       ┆       ┆       │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ eri ┆     ┆ sa  ┆        ┆       ┆       ┆       │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ or  ┆     ┆     ┆        ┆       ┆       ┆       │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ Com ┆     ┆     ┆        ┆       ┆       ┆       │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ ple ┆     ┆     ┆        ┆       ┆       ┆       │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ to  ┆     ┆     ┆        ┆       ┆       ┆       │
# │ 198 ┆ 82  ┆ 171 ┆ CAT ┆ SP  ┆ BRA ┆ Sol ┆ M   ┆ Ens ┆ 200 ┆ Sem ┆ Urbana ┆ CATAN ┆ SP    ┆ BRASI │
# │ 9   ┆     ┆     ┆ AND ┆     ┆ SIL ┆ tei ┆     ┆ ino ┆ 7   ┆ dis ┆        ┆ DUVA  ┆       ┆ L     │
# │     ┆     ┆     ┆ UVA ┆     ┆     ┆ ro  ┆     ┆ Méd ┆     ┆ pen ┆        ┆       ┆       ┆       │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ io  ┆     ┆ sa  ┆        ┆       ┆       ┆       │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ Com ┆     ┆     ┆        ┆       ┆       ┆       │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ ple ┆     ┆     ┆        ┆       ┆       ┆       │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ to  ┆     ┆     ┆        ┆       ┆       ┆       │
# │ 198 ┆ nul ┆ nul ┆ SAN ┆ SP  ┆ BRA ┆ Sol ┆ M   ┆ Ens ┆ 200 ┆ Sem ┆ Urbana ┆ PIRAJ ┆ SP    ┆ BRASI │
# │ 9   ┆ l   ┆ l   ┆ TO  ┆     ┆ SIL ┆ tei ┆     ┆ ino ┆ 7   ┆ dis ┆        ┆ UI    ┆       ┆ L     │
# │     ┆     ┆     ┆ AND ┆     ┆     ┆ ro  ┆     ┆ Méd ┆     ┆ pen ┆        ┆       ┆       ┆       │
# │     ┆     ┆     ┆ RE  ┆     ┆     ┆     ┆     ┆ io  ┆     ┆ sa  ┆        ┆       ┆       ┆       │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ Com ┆     ┆     ┆        ┆       ┆       ┆       │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ ple ┆     ┆     ┆        ┆       ┆       ┆       │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ to  ┆     ┆     ┆        ┆       ┆       ┆       │
# │ 198 ┆ nul ┆ nul ┆ PIR ┆ SP  ┆ BRA ┆ Sol ┆ M   ┆ 3ª  ┆ 200 ┆ Sem ┆ Urbana ┆ PIRAJ ┆ SP    ┆ BRASI │
# │ 9   ┆ l   ┆ l   ┆ AJU ┆     ┆ SIL ┆ tei ┆     ┆ Sér ┆ 7   ┆ dis ┆        ┆ UI    ┆       ┆ L     │
# │     ┆     ┆     ┆ I   ┆     ┆     ┆ ro  ┆     ┆ ie  ┆     ┆ pen ┆        ┆       ┆       ┆       │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ do  ┆     ┆ sa  ┆        ┆       ┆       ┆       │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ Ens ┆     ┆     ┆        ┆       ┆       ┆       │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ ino ┆     ┆     ┆        ┆       ┆       ┆       │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ Méd ┆     ┆     ┆        ┆       ┆       ┆       │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ io  ┆     ┆     ┆        ┆       ┆       ┆       │
# └─────┴─────┴─────┴─────┴─────┴─────┴─────┴─────┴─────┴─────┴─────┴────────┴───────┴───────┴───────┘

# %%
n_rows = df_etl.shape[0]
n_rows
# Out:
# 26569408

# %%
for col in df_etl.columns:
    qtd_nulos = df_etl.select(
        pl.col(col).null_count()
    ).item()
    if qtd_nulos > 0:
        print(f'Coluna {col} tem {qtd_nulos} valores nulos.')
# Out:
# Coluna PESO tem 18598039 valores nulos.
# Coluna ALTURA tem 18588096 valores nulos.
# Coluna DISPENSA tem 474630 valores nulos.

# %%
df_etl.group_by('VINCULACAO_ANO').agg(
    ((pl.col(['PESO', 'ALTURA', 'DISPENSA']).null_count() / pl.len()) * 100).round(2).name.suffix('_qtd_nulos')
)
# Out:
# shape: (18, 4)
# ┌────────────────┬────────────────┬──────────────────┬────────────────────┐
# │ VINCULACAO_ANO ┆ PESO_qtd_nulos ┆ ALTURA_qtd_nulos ┆ DISPENSA_qtd_nulos │
# │ ---            ┆ ---            ┆ ---              ┆ ---                │
# │ str            ┆ f64            ┆ f64              ┆ f64                │
# ╞════════════════╪════════════════╪══════════════════╪════════════════════╡
# │ 2020           ┆ 68.1           ┆ 68.12            ┆ 0.0                │
# │ 2018           ┆ 68.11          ┆ 68.11            ┆ 0.0                │
# │ 2012           ┆ 81.24          ┆ 81.24            ┆ 0.0                │
# │ 2008           ┆ 81.6           ┆ 81.47            ┆ 0.0                │
# │ 2010           ┆ 79.92          ┆ 79.92            ┆ 0.0                │
# │ 2023           ┆ 56.78          ┆ 56.78            ┆ 0.0                │
# │ 2019           ┆ 0.0            ┆ 0.0              ┆ 0.0                │
# │ 2017           ┆ 74.84          ┆ 74.82            ┆ 32.7               │
# │ 2007           ┆ 81.15          ┆ 80.7             ┆ 0.0                │
# │ 2015           ┆ 79.52          ┆ 79.52            ┆ 0.0                │
# │ 2016           ┆ 79.34          ┆ 79.35            ┆ 0.0                │
# │ 2014           ┆ 80.2           ┆ 80.19            ┆ 0.0                │
# │ 2021           ┆ 67.53          ┆ 67.53            ┆ 0.0                │
# │ 2011           ┆ 79.71          ┆ 79.71            ┆ 0.0                │
# │ 2009           ┆ 78.75          ┆ 78.74            ┆ 0.0                │
# │ 2022           ┆ 70.52          ┆ 70.52            ┆ 0.0                │
# │ 2024           ┆ 0.0            ┆ 0.0              ┆ 0.0                │
# │ 2013           ┆ 80.15          ┆ 80.15            ┆ 0.0                │
# └────────────────┴────────────────┴──────────────────┴────────────────────┘

# %%
df_etl = df_etl.drop(['PESO', 'ALTURA'])

# %%
df_etl.select('DISPENSA').unique().to_series().to_list()
# Out:
# ['Com dispensa', None, 'Sem dispensa', 'null']

# %%
for col in df_etl.columns:
    df_etl = df_etl.with_columns(
        pl.col(col).replace('null', None)
    )

# %%
for col in df_etl.columns:
    qtd_nulos = df_etl.select(
        pl.col(col).null_count()
    ).item()
    if qtd_nulos > 0:
        print(f'Coluna {col} tem {qtd_nulos} valores nulos.')
# Out:
# Coluna DISPENSA tem 474635 valores nulos.

# %%
df_etl.select('DISPENSA').unique().to_series().to_list()
# Out:
# [None, 'Com dispensa', 'Sem dispensa']

# %%
df_etl = df_etl.filter(
    pl.col('DISPENSA').is_not_null()
).with_columns(
    situacao = pl.when(
        pl.col('DISPENSA') == 'Sem dispensa'
    ).then(pl.lit('Convocado')).otherwise(pl.lit('Dispensado'))
).with_columns(
    pl.col('situacao').cast(pl.Categorical)
).drop('DISPENSA')

# %%
df_etl.head()
# Out:
# shape: (5, 13)
# ┌─────┬─────┬─────┬────────┬────────┬──────┬───────┬───────┬───────┬───────┬───────┬───────┬───────┐
# │ ANO ┆ MUN ┆ UF_ ┆ PAIS_N ┆ ESTADO ┆ SEXO ┆ ESCOL ┆ VINCU ┆ ZONA_ ┆ MUN_R ┆ UF_RE ┆ PAIS_ ┆ situa │
# │ _NA ┆ _NA ┆ NAS ┆ ASCIME ┆ _CIVIL ┆ ---  ┆ ARIDA ┆ LACAO ┆ RESID ┆ ESIDE ┆ SIDEN ┆ RESID ┆ cao   │
# │ SCI ┆ SCI ┆ CIM ┆ NTO    ┆ ---    ┆ str  ┆ DE    ┆ _ANO  ┆ ENCIA ┆ NCIA  ┆ CIA   ┆ ENCIA ┆ ---   │
# │ MEN ┆ MEN ┆ ENT ┆ ---    ┆ str    ┆      ┆ ---   ┆ ---   ┆ L     ┆ ---   ┆ ---   ┆ ---   ┆ cat   │
# │ TO  ┆ TO  ┆ O   ┆ str    ┆        ┆      ┆ str   ┆ str   ┆ ---   ┆ str   ┆ str   ┆ str   ┆       │
# │ --- ┆ --- ┆ --- ┆        ┆        ┆      ┆       ┆       ┆ str   ┆       ┆       ┆       ┆       │
# │ str ┆ str ┆ str ┆        ┆        ┆      ┆       ┆       ┆       ┆       ┆       ┆       ┆       │
# ╞═════╪═════╪═════╪════════╪════════╪══════╪═══════╪═══════╪═══════╪═══════╪═══════╪═══════╪═══════╡
# │ 198 ┆ DES ┆ SP  ┆ BRASIL ┆ Soltei ┆ M    ┆ Ensin ┆ 2007  ┆ Urban ┆ PIRAS ┆ SP    ┆ BRASI ┆ Convo │
# │ 9   ┆ CAL ┆     ┆        ┆ ro     ┆      ┆ o     ┆       ┆ a     ┆ SUNUN ┆       ┆ L     ┆ cado  │
# │     ┆ VAD ┆     ┆        ┆        ┆      ┆ Médio ┆       ┆       ┆ GA    ┆       ┆       ┆       │
# │     ┆ O   ┆     ┆        ┆        ┆      ┆ Compl ┆       ┆       ┆       ┆       ┆       ┆       │
# │     ┆     ┆     ┆        ┆        ┆      ┆ eto   ┆       ┆       ┆       ┆       ┆       ┆       │
# │ 198 ┆ CAT ┆ SP  ┆ BRASIL ┆ Casado ┆ M    ┆ Ensin ┆ 2007  ┆ Urban ┆ SAO   ┆ SP    ┆ BRASI ┆ Convo │
# │ 9   ┆ AND ┆     ┆        ┆        ┆      ┆ o Sup ┆       ┆ a     ┆ PAULO ┆       ┆ L     ┆ cado  │
# │     ┆ UVA ┆     ┆        ┆        ┆      ┆ erior ┆       ┆       ┆       ┆       ┆       ┆       │
# │     ┆     ┆     ┆        ┆        ┆      ┆ Compl ┆       ┆       ┆       ┆       ┆       ┆       │
# │     ┆     ┆     ┆        ┆        ┆      ┆ eto   ┆       ┆       ┆       ┆       ┆       ┆       │
# │ 198 ┆ CAT ┆ SP  ┆ BRASIL ┆ Soltei ┆ M    ┆ Ensin ┆ 2007  ┆ Urban ┆ CATAN ┆ SP    ┆ BRASI ┆ Convo │
# │ 9   ┆ AND ┆     ┆        ┆ ro     ┆      ┆ o     ┆       ┆ a     ┆ DUVA  ┆       ┆ L     ┆ cado  │
# │     ┆ UVA ┆     ┆        ┆        ┆      ┆ Médio ┆       ┆       ┆       ┆       ┆       ┆       │
# │     ┆     ┆     ┆        ┆        ┆      ┆ Compl ┆       ┆       ┆       ┆       ┆       ┆       │
# │     ┆     ┆     ┆        ┆        ┆      ┆ eto   ┆       ┆       ┆       ┆       ┆       ┆       │
# │ 198 ┆ SAN ┆ SP  ┆ BRASIL ┆ Soltei ┆ M    ┆ Ensin ┆ 2007  ┆ Urban ┆ PIRAJ ┆ SP    ┆ BRASI ┆ Convo │
# │ 9   ┆ TO  ┆     ┆        ┆ ro     ┆      ┆ o     ┆       ┆ a     ┆ UI    ┆       ┆ L     ┆ cado  │
# │     ┆ AND ┆     ┆        ┆        ┆      ┆ Médio ┆       ┆       ┆       ┆       ┆       ┆       │
# │     ┆ RE  ┆     ┆        ┆        ┆      ┆ Compl ┆       ┆       ┆       ┆       ┆       ┆       │
# │     ┆     ┆     ┆        ┆        ┆      ┆ eto   ┆       ┆       ┆       ┆       ┆       ┆       │
# │ 198 ┆ PIR ┆ SP  ┆ BRASIL ┆ Soltei ┆ M    ┆ 3ª    ┆ 2007  ┆ Urban ┆ PIRAJ ┆ SP    ┆ BRASI ┆ Convo │
# │ 9   ┆ AJU ┆     ┆        ┆ ro     ┆      ┆ Série ┆       ┆ a     ┆ UI    ┆       ┆ L     ┆ cado  │
# │     ┆ I   ┆     ┆        ┆        ┆      ┆ do    ┆       ┆       ┆       ┆       ┆       ┆       │
# │     ┆     ┆     ┆        ┆        ┆      ┆ Ensin ┆       ┆       ┆       ┆       ┆       ┆       │
# │     ┆     ┆     ┆        ┆        ┆      ┆ o     ┆       ┆       ┆       ┆       ┆       ┆       │
# │     ┆     ┆     ┆        ┆        ┆      ┆ Médio ┆       ┆       ┆       ┆       ┆       ┆       │
# └─────┴─────┴─────┴────────┴────────┴──────┴───────┴───────┴───────┴───────┴───────┴───────┴───────┘

# %%
df_etl = df_etl.with_columns(
    pl.col('ANO_NASCIMENTO').cast(pl.Int16),
    pl.col('UF_NASCIMENTO').cast(pl.Categorical),
    pl.col('VINCULACAO_ANO').cast(pl.Int16),
    pl.col('UF_RESIDENCIA').cast(pl.Categorical),
).drop(['MUN_NASCIMENTO', 'MUN_RESIDENCIA'])

# %%
n_rows = df_etl.shape[0]
n_rows
# Out:
# 26094773

# %%
df_etl.with_columns(
    nasceu_brasil = pl.col('PAIS_NASCIMENTO') == 'BRASIL',
    reside_brasil = pl.col('PAIS_RESIDENCIA') == 'BRASIL'
).select(
    pl.col(['nasceu_brasil', 'reside_brasil']).value_counts()
)
# Out:
# shape: (2, 2)
# ┌─────────────────┬─────────────────┐
# │ nasceu_brasil   ┆ reside_brasil   │
# │ ---             ┆ ---             │
# │ struct[2]       ┆ struct[2]       │
# ╞═════════════════╪═════════════════╡
# │ {true,26018143} ┆ {false,115261}  │
# │ {false,76630}   ┆ {true,25979512} │
# └─────────────────┴─────────────────┘

# %%
df_etl = df_etl.filter(
    pl.col('PAIS_NASCIMENTO') == 'BRASIL',
    pl.col('PAIS_RESIDENCIA') == 'BRASIL'
).drop(['PAIS_NASCIMENTO', 'PAIS_RESIDENCIA'])

# %%
df_etl.head()
# Out:
# shape: (5, 9)
# ┌───────────┬───────────┬───────────┬──────┬───────────┬──────────┬──────────┬──────────┬──────────┐
# │ ANO_NASCI ┆ UF_NASCIM ┆ ESTADO_CI ┆ SEXO ┆ ESCOLARID ┆ VINCULAC ┆ ZONA_RES ┆ UF_RESID ┆ situacao │
# │ MENTO     ┆ ENTO      ┆ VIL       ┆ ---  ┆ ADE       ┆ AO_ANO   ┆ IDENCIAL ┆ ENCIA    ┆ ---      │
# │ ---       ┆ ---       ┆ ---       ┆ str  ┆ ---       ┆ ---      ┆ ---      ┆ ---      ┆ cat      │
# │ i16       ┆ cat       ┆ str       ┆      ┆ str       ┆ i16      ┆ str      ┆ cat      ┆          │
# ╞═══════════╪═══════════╪═══════════╪══════╪═══════════╪══════════╪══════════╪══════════╪══════════╡
# │ 1989      ┆ SP        ┆ Solteiro  ┆ M    ┆ Ensino    ┆ 2007     ┆ Urbana   ┆ SP       ┆ Convocad │
# │           ┆           ┆           ┆      ┆ Médio     ┆          ┆          ┆          ┆ o        │
# │           ┆           ┆           ┆      ┆ Completo  ┆          ┆          ┆          ┆          │
# │ 1989      ┆ SP        ┆ Casado    ┆ M    ┆ Ensino    ┆ 2007     ┆ Urbana   ┆ SP       ┆ Convocad │
# │           ┆           ┆           ┆      ┆ Superior  ┆          ┆          ┆          ┆ o        │
# │           ┆           ┆           ┆      ┆ Completo  ┆          ┆          ┆          ┆          │
# │ 1989      ┆ SP        ┆ Solteiro  ┆ M    ┆ Ensino    ┆ 2007     ┆ Urbana   ┆ SP       ┆ Convocad │
# │           ┆           ┆           ┆      ┆ Médio     ┆          ┆          ┆          ┆ o        │
# │           ┆           ┆           ┆      ┆ Completo  ┆          ┆          ┆          ┆          │
# │ 1989      ┆ SP        ┆ Solteiro  ┆ M    ┆ Ensino    ┆ 2007     ┆ Urbana   ┆ SP       ┆ Convocad │
# │           ┆           ┆           ┆      ┆ Médio     ┆          ┆          ┆          ┆ o        │
# │           ┆           ┆           ┆      ┆ Completo  ┆          ┆          ┆          ┆          │
# │ 1989      ┆ SP        ┆ Solteiro  ┆ M    ┆ 3ª Série  ┆ 2007     ┆ Urbana   ┆ SP       ┆ Convocad │
# │           ┆           ┆           ┆      ┆ do Ensino ┆          ┆          ┆          ┆ o        │
# │           ┆           ┆           ┆      ┆ Médio     ┆          ┆          ┆          ┆          │
# └───────────┴───────────┴───────────┴──────┴───────────┴──────────┴──────────┴──────────┴──────────┘

# %%
print(df_etl.select('ESTADO_CIVIL').unique().to_series().to_list())
# Out:
# ['Separado Judicialmente', 'Casado', 'ViÃºvo', 'Viúvo', 'Outros', 'Divorciado', 'Solteiro', 'Desquitado']

# %%
df = df_etl.with_columns(
    pl.col('ESTADO_CIVIL').replace({
        'ViÃºvo': 'Viúvo',
        'Separado Judicialmente': 'Divorciado',
        'Desquitado': 'Divorciado',
    })
)

# %%
print(df_etl.select('ESTADO_CIVIL').unique().to_series().to_list())
# Out:
# ['Solteiro', 'Desquitado', 'Viúvo', 'Separado Judicialmente', 'Casado', 'ViÃºvo', 'Outros', 'Divorciado']

# %%
df_etl.select(
    pl.col('ESTADO_CIVIL').value_counts()
).unnest('ESTADO_CIVIL').group_by('ESTADO_CIVIL').agg(
    ((pl.col('count').sum() / n_rows) * 100).round(2)
)
# Out:
# shape: (8, 2)
# ┌────────────────────────┬───────┐
# │ ESTADO_CIVIL           ┆ count │
# │ ---                    ┆ ---   │
# │ str                    ┆ f64   │
# ╞════════════════════════╪═══════╡
# │ Outros                 ┆ 0.86  │
# │ ViÃºvo                 ┆ 0.0   │
# │ Desquitado             ┆ 0.01  │
# │ Casado                 ┆ 1.39  │
# │ Divorciado             ┆ 0.17  │
# │ Viúvo                  ┆ 0.0   │
# │ Solteiro               ┆ 96.95 │
# │ Separado Judicialmente ┆ 0.01  │
# └────────────────────────┴───────┘

# %%
df = df_etl.filter(
    pl.col('ESTADO_CIVIL') == 'Solteiro'
).drop('ESTADO_CIVIL')

# %%
n_rows = df_etl.shape[0]
n_rows
# Out:
# 25935637

# %%
df_etl.head()
# Out:
# shape: (5, 9)
# ┌───────────┬───────────┬───────────┬──────┬───────────┬──────────┬──────────┬──────────┬──────────┐
# │ ANO_NASCI ┆ UF_NASCIM ┆ ESTADO_CI ┆ SEXO ┆ ESCOLARID ┆ VINCULAC ┆ ZONA_RES ┆ UF_RESID ┆ situacao │
# │ MENTO     ┆ ENTO      ┆ VIL       ┆ ---  ┆ ADE       ┆ AO_ANO   ┆ IDENCIAL ┆ ENCIA    ┆ ---      │
# │ ---       ┆ ---       ┆ ---       ┆ str  ┆ ---       ┆ ---      ┆ ---      ┆ ---      ┆ cat      │
# │ i16       ┆ cat       ┆ str       ┆      ┆ str       ┆ i16      ┆ str      ┆ cat      ┆          │
# ╞═══════════╪═══════════╪═══════════╪══════╪═══════════╪══════════╪══════════╪══════════╪══════════╡
# │ 1989      ┆ SP        ┆ Solteiro  ┆ M    ┆ Ensino    ┆ 2007     ┆ Urbana   ┆ SP       ┆ Convocad │
# │           ┆           ┆           ┆      ┆ Médio     ┆          ┆          ┆          ┆ o        │
# │           ┆           ┆           ┆      ┆ Completo  ┆          ┆          ┆          ┆          │
# │ 1989      ┆ SP        ┆ Casado    ┆ M    ┆ Ensino    ┆ 2007     ┆ Urbana   ┆ SP       ┆ Convocad │
# │           ┆           ┆           ┆      ┆ Superior  ┆          ┆          ┆          ┆ o        │
# │           ┆           ┆           ┆      ┆ Completo  ┆          ┆          ┆          ┆          │
# │ 1989      ┆ SP        ┆ Solteiro  ┆ M    ┆ Ensino    ┆ 2007     ┆ Urbana   ┆ SP       ┆ Convocad │
# │           ┆           ┆           ┆      ┆ Médio     ┆          ┆          ┆          ┆ o        │
# │           ┆           ┆           ┆      ┆ Completo  ┆          ┆          ┆          ┆          │
# │ 1989      ┆ SP        ┆ Solteiro  ┆ M    ┆ Ensino    ┆ 2007     ┆ Urbana   ┆ SP       ┆ Convocad │
# │           ┆           ┆           ┆      ┆ Médio     ┆          ┆          ┆          ┆ o        │
# │           ┆           ┆           ┆      ┆ Completo  ┆          ┆          ┆          ┆          │
# │ 1989      ┆ SP        ┆ Solteiro  ┆ M    ┆ 3ª Série  ┆ 2007     ┆ Urbana   ┆ SP       ┆ Convocad │
# │           ┆           ┆           ┆      ┆ do Ensino ┆          ┆          ┆          ┆ o        │
# │           ┆           ┆           ┆      ┆ Médio     ┆          ┆          ┆          ┆          │
# └───────────┴───────────┴───────────┴──────┴───────────┴──────────┴──────────┴──────────┴──────────┘

# %%
print(df_etl.select('SEXO').unique().to_series().to_list())
# Out:
# ['F', 'M']

# %%
df_etl.select(
    pl.col('SEXO').value_counts()
).unnest('SEXO').group_by('SEXO').agg(
    ((pl.col('count').sum() / n_rows) * 100).round(2)
)
# Out:
# shape: (2, 2)
# ┌──────┬───────┐
# │ SEXO ┆ count │
# │ ---  ┆ ---   │
# │ str  ┆ f64   │
# ╞══════╪═══════╡
# │ F    ┆ 0.05  │
# │ M    ┆ 99.95 │
# └──────┴───────┘

# %%
df = df_etl.filter(
    pl.col('SEXO') != 'F'
).drop('SEXO')

# %%
n_rows = df_etl.shape[0]
n_rows
# Out:
# 25935637

# %%
df_etl.head()
# Out:
# shape: (5, 9)
# ┌───────────┬───────────┬───────────┬──────┬───────────┬──────────┬──────────┬──────────┬──────────┐
# │ ANO_NASCI ┆ UF_NASCIM ┆ ESTADO_CI ┆ SEXO ┆ ESCOLARID ┆ VINCULAC ┆ ZONA_RES ┆ UF_RESID ┆ situacao │
# │ MENTO     ┆ ENTO      ┆ VIL       ┆ ---  ┆ ADE       ┆ AO_ANO   ┆ IDENCIAL ┆ ENCIA    ┆ ---      │
# │ ---       ┆ ---       ┆ ---       ┆ str  ┆ ---       ┆ ---      ┆ ---      ┆ ---      ┆ cat      │
# │ i16       ┆ cat       ┆ str       ┆      ┆ str       ┆ i16      ┆ str      ┆ cat      ┆          │
# ╞═══════════╪═══════════╪═══════════╪══════╪═══════════╪══════════╪══════════╪══════════╪══════════╡
# │ 1989      ┆ SP        ┆ Solteiro  ┆ M    ┆ Ensino    ┆ 2007     ┆ Urbana   ┆ SP       ┆ Convocad │
# │           ┆           ┆           ┆      ┆ Médio     ┆          ┆          ┆          ┆ o        │
# │           ┆           ┆           ┆      ┆ Completo  ┆          ┆          ┆          ┆          │
# │ 1989      ┆ SP        ┆ Casado    ┆ M    ┆ Ensino    ┆ 2007     ┆ Urbana   ┆ SP       ┆ Convocad │
# │           ┆           ┆           ┆      ┆ Superior  ┆          ┆          ┆          ┆ o        │
# │           ┆           ┆           ┆      ┆ Completo  ┆          ┆          ┆          ┆          │
# │ 1989      ┆ SP        ┆ Solteiro  ┆ M    ┆ Ensino    ┆ 2007     ┆ Urbana   ┆ SP       ┆ Convocad │
# │           ┆           ┆           ┆      ┆ Médio     ┆          ┆          ┆          ┆ o        │
# │           ┆           ┆           ┆      ┆ Completo  ┆          ┆          ┆          ┆          │
# │ 1989      ┆ SP        ┆ Solteiro  ┆ M    ┆ Ensino    ┆ 2007     ┆ Urbana   ┆ SP       ┆ Convocad │
# │           ┆           ┆           ┆      ┆ Médio     ┆          ┆          ┆          ┆ o        │
# │           ┆           ┆           ┆      ┆ Completo  ┆          ┆          ┆          ┆          │
# │ 1989      ┆ SP        ┆ Solteiro  ┆ M    ┆ 3ª Série  ┆ 2007     ┆ Urbana   ┆ SP       ┆ Convocad │
# │           ┆           ┆           ┆      ┆ do Ensino ┆          ┆          ┆          ┆ o        │
# │           ┆           ┆           ┆      ┆ Médio     ┆          ┆          ┆          ┆          │
# └───────────┴───────────┴───────────┴──────┴───────────┴──────────┴──────────┴──────────┴──────────┘

# %%
print(df_etl.select('ZONA_RESIDENCIAL').unique().to_series().to_list())
# Out:
# ['Rural', 'Urbana']

# %%
df_etl.select(
    pl.col('ZONA_RESIDENCIAL').value_counts()
).unnest('ZONA_RESIDENCIAL').group_by('ZONA_RESIDENCIAL').agg(
    ((pl.col('count').sum() / n_rows) * 100).round(2)
)
# Out:
# shape: (2, 2)
# ┌──────────────────┬───────┐
# │ ZONA_RESIDENCIAL ┆ count │
# │ ---              ┆ ---   │
# │ str              ┆ f64   │
# ╞══════════════════╪═══════╡
# │ Rural            ┆ 12.23 │
# │ Urbana           ┆ 87.77 │
# └──────────────────┴───────┘

# %%
df_etl = df_etl.with_columns(
    pl.col('ZONA_RESIDENCIAL').cast(pl.Categorical)
)

# %%
df_etl.head()
# Out:
# shape: (5, 9)
# ┌───────────┬───────────┬───────────┬──────┬───────────┬──────────┬──────────┬──────────┬──────────┐
# │ ANO_NASCI ┆ UF_NASCIM ┆ ESTADO_CI ┆ SEXO ┆ ESCOLARID ┆ VINCULAC ┆ ZONA_RES ┆ UF_RESID ┆ situacao │
# │ MENTO     ┆ ENTO      ┆ VIL       ┆ ---  ┆ ADE       ┆ AO_ANO   ┆ IDENCIAL ┆ ENCIA    ┆ ---      │
# │ ---       ┆ ---       ┆ ---       ┆ str  ┆ ---       ┆ ---      ┆ ---      ┆ ---      ┆ cat      │
# │ i16       ┆ cat       ┆ str       ┆      ┆ str       ┆ i16      ┆ cat      ┆ cat      ┆          │
# ╞═══════════╪═══════════╪═══════════╪══════╪═══════════╪══════════╪══════════╪══════════╪══════════╡
# │ 1989      ┆ SP        ┆ Solteiro  ┆ M    ┆ Ensino    ┆ 2007     ┆ Urbana   ┆ SP       ┆ Convocad │
# │           ┆           ┆           ┆      ┆ Médio     ┆          ┆          ┆          ┆ o        │
# │           ┆           ┆           ┆      ┆ Completo  ┆          ┆          ┆          ┆          │
# │ 1989      ┆ SP        ┆ Casado    ┆ M    ┆ Ensino    ┆ 2007     ┆ Urbana   ┆ SP       ┆ Convocad │
# │           ┆           ┆           ┆      ┆ Superior  ┆          ┆          ┆          ┆ o        │
# │           ┆           ┆           ┆      ┆ Completo  ┆          ┆          ┆          ┆          │
# │ 1989      ┆ SP        ┆ Solteiro  ┆ M    ┆ Ensino    ┆ 2007     ┆ Urbana   ┆ SP       ┆ Convocad │
# │           ┆           ┆           ┆      ┆ Médio     ┆          ┆          ┆          ┆ o        │
# │           ┆           ┆           ┆      ┆ Completo  ┆          ┆          ┆          ┆          │
# │ 1989      ┆ SP        ┆ Solteiro  ┆ M    ┆ Ensino    ┆ 2007     ┆ Urbana   ┆ SP       ┆ Convocad │
# │           ┆           ┆           ┆      ┆ Médio     ┆          ┆          ┆          ┆ o        │
# │           ┆           ┆           ┆      ┆ Completo  ┆          ┆          ┆          ┆          │
# │ 1989      ┆ SP        ┆ Solteiro  ┆ M    ┆ 3ª Série  ┆ 2007     ┆ Urbana   ┆ SP       ┆ Convocad │
# │           ┆           ┆           ┆      ┆ do Ensino ┆          ┆          ┆          ┆ o        │
# │           ┆           ┆           ┆      ┆ Médio     ┆          ┆          ┆          ┆          │
# └───────────┴───────────┴───────────┴──────┴───────────┴──────────┴──────────┴──────────┴──────────┘

# %%
print(df_etl.select('ESCOLARIDADE').unique().to_series().to_list())
# Out:
# ['4ª Série do Ensino Fundamental', '8Â° Semestre - Ensino Superior', '6Â° Semestre - Ensino Superior', '7ª Série do Ensino Fundamental', '10° Semestre do Ensino Superior', 'Pós-Graduação', '9Â° Semestre - Ensino Superior', '7° Semestre do Ensino Superior', '3ª Série do Ensino Fundamental', '6Â° Ano - Ensino Fundamental', '2Â° Semestre - Ensino Superior', 'PÃ³s-GraduaÃ§â\x95\x9eo', 'Pós-Doutorado', 'PÃ³s-GraduaÃ§Ã£o', '2° Semestre do Ensino Superior', '5° Semestre - Ensino Superior', '8° Semestre do Ensino Superior', '5° Ano - Ensino Fundamental', '1ª Série do Ensino Fundamental', '1° Ano - Ensino Fundamental', '2° Ano - Ensino Médio', '9° Semestre - Ensino Superior', '4° Ano - Ensino Fundamental', '4° Semestre - Ensino Superior', '3° Ano - Ensino Médio', '1ª Série do Ensino Médio', 'Ensino MÃ©dio Completo', '6° Semestre do Ensino Superior', '7Â° Semestre - Ensino Superior', '5° Semestre do Ensino Superior', '9ª Série do Ensino Fundamental', '8° Ano - Ensino Fundamental', '2° Ano - Ensino Fundamental', 'Ensino Superior Completo', '6° Semestre - Ensino Superior', '6° Ano - Ensino Fundamental', '2ª Série do Ensino Fundamental', 'Ensino Médio Completo', '4ª Série do Ensino Médio', 'Alfabetizado', '4Â° Ano - Ensino MÃ©dio (Profissionalizante)', '5Â° Ano - Ensino Fundamental', '10° Semestre - Ensino Superior', '1Â° Ano - Ensino MÃ©dio', '4Â° Semestre - Ensino Superior', '7Â° Ano - Ensino Fundamental', '1° Ano - Ensino Médio', '1Â° Semestre - Ensino Superior', '1Â° Ano - Ensino Fundamental', '1° Semestre - Ensino Superior', '3° Semestre do Ensino Superior', '8Â° Ano - Ensino Fundamental', 'Analfabeto', '7° Ano - Ensino Fundamental', 'Ensino Fundamental Completo', '9° Ano - Ensino Fundamental', 'Doutorado', '2Â° Ano - Ensino MÃ©dio', '4° Semestre do Ensino Superior', '2ª Série do Ensino Médio', '2Â° Ano - Ensino Fundamental', 'Mestrado', '10Â° Semestre - Ensino Superior', '4Â° Ano - Ensino Fundamental', '6ª Série do Ensino Fundamental', '8° Semestre - Ensino Superior', '8ª Série do Ensino Fundamental', '3Â° Ano - Ensino MÃ©dio', '7° Semestre - Ensino Superior', '5ª Série do Ensino Fundamental', '9Â° Ano - Ensino Fundamental', '3Â° Semestre - Ensino Superior', '2° Semestre - Ensino Superior', '9° Semestre do Ensino Superior', '5Â° Semestre - Ensino Superior', '1° Semestre do Ensino Superior', '3° Ano - Ensino Fundamental', 'PÃ³s-Doutorado', '4° Ano - Ensino Médio (Profissionalizante)', '3ª Série do Ensino Médio', '3° Semestre - Ensino Superior', '3Â° Ano - Ensino Fundamental']

# %%
df_etl = df_etl.with_columns(
    pl.col('ESCOLARIDADE').str.replace_many({
        'Â°': '°',
        'Ã©': 'é',        
        'Ã³s': 'ó',
        'Ã§Ã£o': 'ção',
        'Ã§â\x95\x9eo': 'ção'
    }, ascii_case_insensitive=True)
)

# %%
print(df_etl.select('ESCOLARIDADE').unique().to_series().to_list())
# Out:
# ['5° Semestre do Ensino Superior', '2° Semestre - Ensino Superior', '7° Ano - Ensino Fundamental', 'Analfabeto', 'Pós-Doutorado', '5° Semestre - Ensino Superior', '1° Semestre - Ensino Superior', '8° Ano - Ensino Fundamental', '4ª Série do Ensino Fundamental', 'Mestrado', '8° Semestre do Ensino Superior', '2° Semestre do Ensino Superior', 'Ensino Fundamental Completo', '4° Semestre - Ensino Superior', '1° Ano - Ensino Médio', '2ª Série do Ensino Médio', 'Doutorado', '8° Semestre - Ensino Superior', 'Ensino Superior Completo', '10° Semestre - Ensino Superior', '8ª Série do Ensino Fundamental', 'Pó-Doutorado', '3° Semestre - Ensino Superior', '1ª Série do Ensino Fundamental', '6ª Série do Ensino Fundamental', '6° Semestre - Ensino Superior', '7ª Série do Ensino Fundamental', '1ª Série do Ensino Médio', 'Ensino Médio Completo', '2° Ano - Ensino Médio', '5° Ano - Ensino Fundamental', '1° Semestre do Ensino Superior', '10° Semestre do Ensino Superior', 'Alfabetizado', '9° Ano - Ensino Fundamental', '5ª Série do Ensino Fundamental', '6° Semestre do Ensino Superior', '9ª Série do Ensino Fundamental', '4° Semestre do Ensino Superior', '1° Ano - Ensino Fundamental', '3° Ano - Ensino Médio', '2° Ano - Ensino Fundamental', '9° Semestre - Ensino Superior', '3ª Série do Ensino Médio', '9° Semestre do Ensino Superior', 'Pó-Graduação', '7° Semestre do Ensino Superior', '7° Semestre - Ensino Superior', '6° Ano - Ensino Fundamental', '4° Ano - Ensino Médio (Profissionalizante)', '4° Ano - Ensino Fundamental', '2ª Série do Ensino Fundamental', '3° Semestre do Ensino Superior', '4ª Série do Ensino Médio', 'Pós-Graduação', '3° Ano - Ensino Fundamental', '3ª Série do Ensino Fundamental']

# %%
ensino_fundamental = df_etl.select('ESCOLARIDADE').filter(
    pl.col('ESCOLARIDADE').str.contains('Ensino Fundamental')
).unique().to_series().to_list()

# %%
ensino_medio = df_etl.select('ESCOLARIDADE').filter(
    pl.col('ESCOLARIDADE').str.contains('Ensino Médio')
).unique().to_series().to_list()

# %%
graduacao = df_etl.select('ESCOLARIDADE').filter(
    pl.col('ESCOLARIDADE').str.contains('Ensino Superior')
).unique().to_series().to_list()

# %%
ordem_escolaridade = [
    'Analfabeto',
    'Alfabetizado',
    'Ensino Fundamental',
    'Ensino Médio',
    'Graduação',
    'Pós-Graduação'
]

# %%
df_etl = df_etl.with_columns(
    nivel_educacional = pl.when(pl.col('ESCOLARIDADE') == 'Analfabeto')
        .then(pl.lit('Analfabeto'))
        .when(pl.col('ESCOLARIDADE') == 'Alfabetizado')
        .then(pl.lit('Alfabetizado'))
        .when(pl.col('ESCOLARIDADE').is_in(ensino_fundamental))
        .then(pl.lit('Ensino Fundamental'))
        .when(pl.col('ESCOLARIDADE').is_in(ensino_medio))
        .then(pl.lit('Ensino Médio'))
        .when(pl.col('ESCOLARIDADE').is_in(graduacao))
        .then(pl.lit('Graduação'))
        .otherwise(pl.lit('Pós-Graduação'))
).with_columns(
    pl.col('nivel_educacional').cast(pl.Enum(ordem_escolaridade))
).drop('ESCOLARIDADE')

# %%
cols_maiusculas = df_etl.columns
cols_minusculas = [col.lower() for col in df_etl.columns]
cols_transformadas = dict(zip(cols_maiusculas, cols_minusculas))

# %%
df_etl = df_etl.rename(cols_transformadas)

# %%
df_etl.head()
# Out:
# shape: (5, 9)
# ┌───────────┬───────────┬───────────┬──────┬───────────┬──────────┬──────────┬──────────┬──────────┐
# │ ano_nasci ┆ uf_nascim ┆ estado_ci ┆ sexo ┆ vinculaca ┆ zona_res ┆ uf_resid ┆ situacao ┆ nivel_ed │
# │ mento     ┆ ento      ┆ vil       ┆ ---  ┆ o_ano     ┆ idencial ┆ encia    ┆ ---      ┆ ucaciona │
# │ ---       ┆ ---       ┆ ---       ┆ str  ┆ ---       ┆ ---      ┆ ---      ┆ cat      ┆ l        │
# │ i16       ┆ cat       ┆ str       ┆      ┆ i16       ┆ cat      ┆ cat      ┆          ┆ ---      │
# │           ┆           ┆           ┆      ┆           ┆          ┆          ┆          ┆ enum     │
# ╞═══════════╪═══════════╪═══════════╪══════╪═══════════╪══════════╪══════════╪══════════╪══════════╡
# │ 1989      ┆ SP        ┆ Solteiro  ┆ M    ┆ 2007      ┆ Urbana   ┆ SP       ┆ Convocad ┆ Ensino   │
# │           ┆           ┆           ┆      ┆           ┆          ┆          ┆ o        ┆ Médio    │
# │ 1989      ┆ SP        ┆ Casado    ┆ M    ┆ 2007      ┆ Urbana   ┆ SP       ┆ Convocad ┆ Graduaçã │
# │           ┆           ┆           ┆      ┆           ┆          ┆          ┆ o        ┆ o        │
# │ 1989      ┆ SP        ┆ Solteiro  ┆ M    ┆ 2007      ┆ Urbana   ┆ SP       ┆ Convocad ┆ Ensino   │
# │           ┆           ┆           ┆      ┆           ┆          ┆          ┆ o        ┆ Médio    │
# │ 1989      ┆ SP        ┆ Solteiro  ┆ M    ┆ 2007      ┆ Urbana   ┆ SP       ┆ Convocad ┆ Ensino   │
# │           ┆           ┆           ┆      ┆           ┆          ┆          ┆ o        ┆ Médio    │
# │ 1989      ┆ SP        ┆ Solteiro  ┆ M    ┆ 2007      ┆ Urbana   ┆ SP       ┆ Convocad ┆ Ensino   │
# │           ┆           ┆           ┆      ┆           ┆          ┆          ┆ o        ┆ Médio    │
# └───────────┴───────────┴───────────┴──────┴───────────┴──────────┴──────────┴──────────┴──────────┘

# %%
df_etl.shape
# Out:
# (25935637, 9)

# %%
df_etl.write_parquet(
    'dados',
    partition_by='vinculacao_ano'
)

# %% [markdown]
# # EDA

# %% [markdown]
# ## ANÁLISES UNIVARIADAS

# %%
df_etl.head()
# Out:
# shape: (5, 9)
# ┌───────────┬───────────┬───────────┬──────┬───────────┬──────────┬──────────┬──────────┬──────────┐
# │ ano_nasci ┆ uf_nascim ┆ estado_ci ┆ sexo ┆ vinculaca ┆ zona_res ┆ uf_resid ┆ situacao ┆ nivel_ed │
# │ mento     ┆ ento      ┆ vil       ┆ ---  ┆ o_ano     ┆ idencial ┆ encia    ┆ ---      ┆ ucaciona │
# │ ---       ┆ ---       ┆ ---       ┆ str  ┆ ---       ┆ ---      ┆ ---      ┆ cat      ┆ l        │
# │ i16       ┆ cat       ┆ str       ┆      ┆ i16       ┆ cat      ┆ cat      ┆          ┆ ---      │
# │           ┆           ┆           ┆      ┆           ┆          ┆          ┆          ┆ enum     │
# ╞═══════════╪═══════════╪═══════════╪══════╪═══════════╪══════════╪══════════╪══════════╪══════════╡
# │ 1989      ┆ SP        ┆ Solteiro  ┆ M    ┆ 2007      ┆ Urbana   ┆ SP       ┆ Convocad ┆ Ensino   │
# │           ┆           ┆           ┆      ┆           ┆          ┆          ┆ o        ┆ Médio    │
# │ 1989      ┆ SP        ┆ Casado    ┆ M    ┆ 2007      ┆ Urbana   ┆ SP       ┆ Convocad ┆ Graduaçã │
# │           ┆           ┆           ┆      ┆           ┆          ┆          ┆ o        ┆ o        │
# │ 1989      ┆ SP        ┆ Solteiro  ┆ M    ┆ 2007      ┆ Urbana   ┆ SP       ┆ Convocad ┆ Ensino   │
# │           ┆           ┆           ┆      ┆           ┆          ┆          ┆ o        ┆ Médio    │
# │ 1989      ┆ SP        ┆ Solteiro  ┆ M    ┆ 2007      ┆ Urbana   ┆ SP       ┆ Convocad ┆ Ensino   │
# │           ┆           ┆           ┆      ┆           ┆          ┆          ┆ o        ┆ Médio    │
# │ 1989      ┆ SP        ┆ Solteiro  ┆ M    ┆ 2007      ┆ Urbana   ┆ SP       ┆ Convocad ┆ Ensino   │
# │           ┆           ┆           ┆      ┆           ┆          ┆          ┆ o        ┆ Médio    │
# └───────────┴───────────┴───────────┴──────┴───────────┴──────────┴──────────┴──────────┴──────────┘

# %%
anos = sorted(df_etl.select('vinculacao_ano').unique().to_series().to_list())

# %%
df_eda_edu = df_etl.group_by(['vinculacao_ano', 'nivel_educacional']).agg(
    qtd = pl.len()
).with_columns(
    qtd_pct = ((pl.col('qtd') / pl.col('qtd').sum().over('vinculacao_ano')) * 100).round(2)
).sort(['vinculacao_ano', 'nivel_educacional'], descending=False)

# %% [markdown]
# ### NÍVEL DE ESCOLARIDADE DOS ALISTADOS

# %%
df_eda_edu.head(10)
# Out:
# shape: (10, 4)
# ┌────────────────┬────────────────────┬────────┬─────────┐
# │ vinculacao_ano ┆ nivel_educacional  ┆ qtd    ┆ qtd_pct │
# │ ---            ┆ ---                ┆ ---    ┆ ---     │
# │ i16            ┆ enum               ┆ u32    ┆ f64     │
# ╞════════════════╪════════════════════╪════════╪═════════╡
# │ 2007           ┆ Analfabeto         ┆ 9307   ┆ 0.58    │
# │ 2007           ┆ Alfabetizado       ┆ 23776  ┆ 1.47    │
# │ 2007           ┆ Ensino Fundamental ┆ 555951 ┆ 34.46   │
# │ 2007           ┆ Ensino Médio       ┆ 951280 ┆ 58.97   │
# │ 2007           ┆ Graduação          ┆ 72718  ┆ 4.51    │
# │ 2007           ┆ Pós-Graduação      ┆ 215    ┆ 0.01    │
# │ 2008           ┆ Analfabeto         ┆ 19810  ┆ 1.15    │
# │ 2008           ┆ Alfabetizado       ┆ 36436  ┆ 2.12    │
# │ 2008           ┆ Ensino Fundamental ┆ 650324 ┆ 37.79   │
# │ 2008           ┆ Ensino Médio       ┆ 943045 ┆ 54.8    │
# └────────────────┴────────────────────┴────────┴─────────┘

# %%
fig, ax = plt.subplots(figsize=(10, 5))

marcadores = ['o', '>', 'd', 's', 'P', 'x']
cores = plt.get_cmap('Dark2').colors

for (nivel_educacional, grupo), marcador, cor in zip(df_eda_edu.group_by('nivel_educacional', maintain_order=True), marcadores, cores):
    ax.plot(
        grupo.select('vinculacao_ano'),
        grupo.select('qtd_pct'),
        label=nivel_educacional,
        marker=marcador,
        color=cor
    )

ax.tick_params('x', rotation=90)
ax.set_xticks(anos)
ax.legend(loc='upper left', bbox_to_anchor=(1, 1))
ax.grid()
ax.set_ylim(0, 100)
ax.set_ylabel('Quantidade (%)')
ax.set_xlabel('Ano')

plt.tight_layout()
fig.savefig('pt/historico_nivel_educacional_alistados.png', dpi=300, bbox_inches='tight')
plt.show()

# %%
renomeacao_niveis_educacionais = {
    'Analfabeto': 'Illiterate',
    'Alfabetizado': 'Literate',
    'Ensino Fundamental': 'Elementary School',
    'Ensino Médio': 'High School',
    'Graduação': 'Bachelor\'s Degree',
    'Pós-Graduação': 'Post-graduate'
}

# %%
df_eda_edu = df_eda_edu.with_columns(
    pl.col("nivel_educacional").cast(pl.String).str.replace_many(renomeacao_niveis_educacionais).cast(pl.Categorical)
)

# %%
fig, ax = plt.subplots(figsize=(10, 5))

marcadores = ['o', '>', 'd', 's', 'P', 'x']
cores = plt.get_cmap('Dark2').colors

for (nivel_educacional, grupo), marcador, cor in zip(df_eda_edu.group_by('nivel_educacional', maintain_order=True), marcadores, cores):
    ax.plot(
        grupo.select('vinculacao_ano'),
        grupo.select('qtd_pct'),
        label=nivel_educacional,
        marker=marcador,
        color=cor
    )

ax.tick_params('x', rotation=90)
ax.set_xticks(anos)
ax.legend(loc='upper left', bbox_to_anchor=(1, 1))
ax.grid()
ax.set_ylim(0, 100)
ax.set_ylabel('Percentage')
ax.set_xlabel('Year')

plt.tight_layout()
fig.savefig('en/plot_educational_level.png', dpi=300, bbox_inches='tight')
plt.show()

# %% [markdown]
# ### SITUAÇÃO MILITAR DOS ALISTADOS

# %%
df_etl.head()
# Out:
# shape: (5, 9)
# ┌───────────┬───────────┬───────────┬──────┬───────────┬──────────┬──────────┬──────────┬──────────┐
# │ ano_nasci ┆ uf_nascim ┆ estado_ci ┆ sexo ┆ vinculaca ┆ zona_res ┆ uf_resid ┆ situacao ┆ nivel_ed │
# │ mento     ┆ ento      ┆ vil       ┆ ---  ┆ o_ano     ┆ idencial ┆ encia    ┆ ---      ┆ ucaciona │
# │ ---       ┆ ---       ┆ ---       ┆ str  ┆ ---       ┆ ---      ┆ ---      ┆ cat      ┆ l        │
# │ i16       ┆ cat       ┆ str       ┆      ┆ i16       ┆ cat      ┆ cat      ┆          ┆ ---      │
# │           ┆           ┆           ┆      ┆           ┆          ┆          ┆          ┆ enum     │
# ╞═══════════╪═══════════╪═══════════╪══════╪═══════════╪══════════╪══════════╪══════════╪══════════╡
# │ 1989      ┆ SP        ┆ Solteiro  ┆ M    ┆ 2007      ┆ Urbana   ┆ SP       ┆ Convocad ┆ Ensino   │
# │           ┆           ┆           ┆      ┆           ┆          ┆          ┆ o        ┆ Médio    │
# │ 1989      ┆ SP        ┆ Casado    ┆ M    ┆ 2007      ┆ Urbana   ┆ SP       ┆ Convocad ┆ Graduaçã │
# │           ┆           ┆           ┆      ┆           ┆          ┆          ┆ o        ┆ o        │
# │ 1989      ┆ SP        ┆ Solteiro  ┆ M    ┆ 2007      ┆ Urbana   ┆ SP       ┆ Convocad ┆ Ensino   │
# │           ┆           ┆           ┆      ┆           ┆          ┆          ┆ o        ┆ Médio    │
# │ 1989      ┆ SP        ┆ Solteiro  ┆ M    ┆ 2007      ┆ Urbana   ┆ SP       ┆ Convocad ┆ Ensino   │
# │           ┆           ┆           ┆      ┆           ┆          ┆          ┆ o        ┆ Médio    │
# │ 1989      ┆ SP        ┆ Solteiro  ┆ M    ┆ 2007      ┆ Urbana   ┆ SP       ┆ Convocad ┆ Ensino   │
# │           ┆           ┆           ┆      ┆           ┆          ┆          ┆ o        ┆ Médio    │
# └───────────┴───────────┴───────────┴──────┴───────────┴──────────┴──────────┴──────────┴──────────┘

# %%
df_eda_convocacao = df_etl.group_by('vinculacao_ano', 'situacao').agg(
    qtd = pl.len()
).with_columns(
    qtd_pct = ((pl.col('qtd') / pl.col('qtd').sum().over('vinculacao_ano')) * 100).round(2)
).sort('vinculacao_ano', descending=False)

# %%
df_eda_convocacao.head()
# Out:
# shape: (5, 4)
# ┌────────────────┬────────────┬─────────┬─────────┐
# │ vinculacao_ano ┆ situacao   ┆ qtd     ┆ qtd_pct │
# │ ---            ┆ ---        ┆ ---     ┆ ---     │
# │ i16            ┆ cat        ┆ u32     ┆ f64     │
# ╞════════════════╪════════════╪═════════╪═════════╡
# │ 2007           ┆ Dispensado ┆ 1068306 ┆ 66.22   │
# │ 2007           ┆ Convocado  ┆ 544941  ┆ 33.78   │
# │ 2008           ┆ Dispensado ┆ 1190439 ┆ 69.17   │
# │ 2008           ┆ Convocado  ┆ 530497  ┆ 30.83   │
# │ 2009           ┆ Dispensado ┆ 1003134 ┆ 65.24   │
# └────────────────┴────────────┴─────────┴─────────┘

# %%
fig, ax = plt.subplots(figsize=(10, 5))

marcadores = ['o', '^']
cores = plt.get_cmap('Dark2').colors

for (convocacao, grupo), marcador, cor in zip(df_eda_convocacao.group_by('situacao'), marcadores, cores):
    plt.plot(
        grupo.select('vinculacao_ano'),
        grupo.select('qtd_pct'),
        label=convocacao,
        marker=marcador,
        color=cor
    )

ax.tick_params('x', rotation=90)
ax.set_xticks(anos)
ax.legend(loc='upper left', bbox_to_anchor=(1, 1))
ax.grid()
ax.set_ylim(0, 100)
ax.set_ylabel('Quantidade (%)')
ax.set_xlabel('Ano')

plt.tight_layout()
fig.savefig('pt/historico_alistados_convocados_dispensados.png', dpi=300, bbox_inches='tight')
plt.show()

# %%
renomeacao_situacao_militar = {
    'Convocado': 'Conscripted',
    'Dispensado': 'discharged'
}

# %%
df_eda_convocacao = df_eda_convocacao.with_columns(
    pl.col('situacao').cast(pl.String).str.replace_many(renomeacao_situacao_militar).cast(pl.Categorical)
)

# %%
fig, ax = plt.subplots(figsize=(10, 5))

marcadores = ['o', '^']
cores = plt.get_cmap('Dark2').colors

for (situacao, grupo), marcador, cor in zip(df_eda_convocacao.group_by('situacao'), marcadores, cores):
    plt.plot(
        grupo.select('vinculacao_ano'),
        grupo.select('qtd_pct'),
        label=situacao,
        marker=marcador,
        color=cor
    )

ax.tick_params('x', rotation=90)
ax.set_xticks(anos)
ax.legend(loc='upper left', bbox_to_anchor=(1, 1))
ax.grid()
ax.set_ylim(0, 100)
ax.set_ylabel('Percentage')
ax.set_xlabel('Year')

plt.tight_layout()
fig.savefig('en/plot_discharged_conscripted_men.png', dpi=300, bbox_inches='tight')
plt.show()

# %% [markdown]
# ### ONDE OS ALISTADOS RESIDEM?

# %%
df_etl.head()
# Out:
# shape: (5, 9)
# ┌───────────┬───────────┬───────────┬──────┬───────────┬──────────┬──────────┬──────────┬──────────┐
# │ ano_nasci ┆ uf_nascim ┆ estado_ci ┆ sexo ┆ vinculaca ┆ zona_res ┆ uf_resid ┆ situacao ┆ nivel_ed │
# │ mento     ┆ ento      ┆ vil       ┆ ---  ┆ o_ano     ┆ idencial ┆ encia    ┆ ---      ┆ ucaciona │
# │ ---       ┆ ---       ┆ ---       ┆ str  ┆ ---       ┆ ---      ┆ ---      ┆ cat      ┆ l        │
# │ i16       ┆ cat       ┆ str       ┆      ┆ i16       ┆ cat      ┆ cat      ┆          ┆ ---      │
# │           ┆           ┆           ┆      ┆           ┆          ┆          ┆          ┆ enum     │
# ╞═══════════╪═══════════╪═══════════╪══════╪═══════════╪══════════╪══════════╪══════════╪══════════╡
# │ 1989      ┆ SP        ┆ Solteiro  ┆ M    ┆ 2007      ┆ Urbana   ┆ SP       ┆ Convocad ┆ Ensino   │
# │           ┆           ┆           ┆      ┆           ┆          ┆          ┆ o        ┆ Médio    │
# │ 1989      ┆ SP        ┆ Casado    ┆ M    ┆ 2007      ┆ Urbana   ┆ SP       ┆ Convocad ┆ Graduaçã │
# │           ┆           ┆           ┆      ┆           ┆          ┆          ┆ o        ┆ o        │
# │ 1989      ┆ SP        ┆ Solteiro  ┆ M    ┆ 2007      ┆ Urbana   ┆ SP       ┆ Convocad ┆ Ensino   │
# │           ┆           ┆           ┆      ┆           ┆          ┆          ┆ o        ┆ Médio    │
# │ 1989      ┆ SP        ┆ Solteiro  ┆ M    ┆ 2007      ┆ Urbana   ┆ SP       ┆ Convocad ┆ Ensino   │
# │           ┆           ┆           ┆      ┆           ┆          ┆          ┆ o        ┆ Médio    │
# │ 1989      ┆ SP        ┆ Solteiro  ┆ M    ┆ 2007      ┆ Urbana   ┆ SP       ┆ Convocad ┆ Ensino   │
# │           ┆           ┆           ┆      ┆           ┆          ┆          ┆ o        ┆ Médio    │
# └───────────┴───────────┴───────────┴──────┴───────────┴──────────┴──────────┴──────────┴──────────┘

# %%
df_eda_zonaresidencia = df_etl.group_by(['vinculacao_ano', 'zona_residencial']).agg(
    qtd = pl.len()
).with_columns(
    qtd_pct = ((pl.col('qtd') / pl.col('qtd').sum().over('vinculacao_ano')) * 100).round(2)
).sort('vinculacao_ano', descending=False)

# %%
df_eda_zonaresidencia.head()
# Out:
# shape: (5, 4)
# ┌────────────────┬──────────────────┬─────────┬─────────┐
# │ vinculacao_ano ┆ zona_residencial ┆ qtd     ┆ qtd_pct │
# │ ---            ┆ ---              ┆ ---     ┆ ---     │
# │ i16            ┆ cat              ┆ u32     ┆ f64     │
# ╞════════════════╪══════════════════╪═════════╪═════════╡
# │ 2007           ┆ Urbana           ┆ 1402723 ┆ 86.95   │
# │ 2007           ┆ Rural            ┆ 210524  ┆ 13.05   │
# │ 2008           ┆ Urbana           ┆ 1447598 ┆ 84.12   │
# │ 2008           ┆ Rural            ┆ 273338  ┆ 15.88   │
# │ 2009           ┆ Urbana           ┆ 1370878 ┆ 89.15   │
# └────────────────┴──────────────────┴─────────┴─────────┘

# %%
fig, ax = plt.subplots(figsize=(10, 5))

marcadores = ['o', '^']
cores = plt.get_cmap('Dark2').colors

for (zona_residencial, grupo), marcador, cor in zip(df_eda_zonaresidencia.group_by('zona_residencial'), marcadores, cores):
    plt.plot(
        grupo.select('vinculacao_ano'),
        grupo.select('qtd_pct'),
        label=zona_residencial,
        marker=marcador,
        color=cor
    )

ax.tick_params('x', rotation=90)
ax.set_xticks(anos)
ax.legend(loc='upper left', bbox_to_anchor=(1, 1))
ax.grid()
ax.set_ylim(0, 100)
ax.set_ylabel('Quantidade (%)')
ax.set_xlabel('Ano')

plt.tight_layout()
fig.savefig('pt/historico_zona_residencial_alistados.png', dpi=300, bbox_inches='tight')
plt.show()

# %%
df_eda_zonaresidencia = df_eda_zonaresidencia.with_columns(
    pl.col('zona_residencial').replace('Urbana', 'Urban')
)

# %%
fig, ax = plt.subplots(figsize=(10, 5))

marcadores = ['o', '^']
cores = plt.get_cmap('Dark2').colors

for (zona_residencial, grupo), marcador, cor in zip(df_eda_zonaresidencia.group_by('zona_residencial'), marcadores, cores):
    plt.plot(
        grupo.select('vinculacao_ano'),
        grupo.select('qtd_pct'),
        label=zona_residencial,
        marker=marcador,
        color=cor
    )

ax.tick_params('x', rotation=90)
ax.set_xticks(anos)
ax.legend(loc='upper left', bbox_to_anchor=(1, 1))
ax.grid()
ax.set_ylim(0, 100)
ax.set_ylabel('Percentage')
ax.set_xlabel('Year')

plt.tight_layout()
fig.savefig('en/plot_where_men_live.png', dpi=300, bbox_inches='tight')
plt.show()

# %% [markdown]
# ### QUANTIDADE DE  ALISTADOS POR ANO

# %%
df_etl.head()
# Out:
# shape: (5, 9)
# ┌───────────┬───────────┬───────────┬──────┬───────────┬──────────┬──────────┬──────────┬──────────┐
# │ ano_nasci ┆ uf_nascim ┆ estado_ci ┆ sexo ┆ vinculaca ┆ zona_res ┆ uf_resid ┆ situacao ┆ nivel_ed │
# │ mento     ┆ ento      ┆ vil       ┆ ---  ┆ o_ano     ┆ idencial ┆ encia    ┆ ---      ┆ ucaciona │
# │ ---       ┆ ---       ┆ ---       ┆ str  ┆ ---       ┆ ---      ┆ ---      ┆ cat      ┆ l        │
# │ i16       ┆ cat       ┆ str       ┆      ┆ i16       ┆ cat      ┆ cat      ┆          ┆ ---      │
# │           ┆           ┆           ┆      ┆           ┆          ┆          ┆          ┆ enum     │
# ╞═══════════╪═══════════╪═══════════╪══════╪═══════════╪══════════╪══════════╪══════════╪══════════╡
# │ 1989      ┆ SP        ┆ Solteiro  ┆ M    ┆ 2007      ┆ Urbana   ┆ SP       ┆ Convocad ┆ Ensino   │
# │           ┆           ┆           ┆      ┆           ┆          ┆          ┆ o        ┆ Médio    │
# │ 1989      ┆ SP        ┆ Casado    ┆ M    ┆ 2007      ┆ Urbana   ┆ SP       ┆ Convocad ┆ Graduaçã │
# │           ┆           ┆           ┆      ┆           ┆          ┆          ┆ o        ┆ o        │
# │ 1989      ┆ SP        ┆ Solteiro  ┆ M    ┆ 2007      ┆ Urbana   ┆ SP       ┆ Convocad ┆ Ensino   │
# │           ┆           ┆           ┆      ┆           ┆          ┆          ┆ o        ┆ Médio    │
# │ 1989      ┆ SP        ┆ Solteiro  ┆ M    ┆ 2007      ┆ Urbana   ┆ SP       ┆ Convocad ┆ Ensino   │
# │           ┆           ┆           ┆      ┆           ┆          ┆          ┆ o        ┆ Médio    │
# │ 1989      ┆ SP        ┆ Solteiro  ┆ M    ┆ 2007      ┆ Urbana   ┆ SP       ┆ Convocad ┆ Ensino   │
# │           ┆           ┆           ┆      ┆           ┆          ┆          ┆ o        ┆ Médio    │
# └───────────┴───────────┴───────────┴──────┴───────────┴──────────┴──────────┴──────────┴──────────┘

# %%
df_eda_qtd_alistados = df_etl.group_by(['vinculacao_ano']).agg(
    qtd = pl.len()
).sort('vinculacao_ano', descending=False)

# %%
df_eda_qtd_alistados.head()
# Out:
# shape: (5, 2)
# ┌────────────────┬─────────┐
# │ vinculacao_ano ┆ qtd     │
# │ ---            ┆ ---     │
# │ i16            ┆ u32     │
# ╞════════════════╪═════════╡
# │ 2007           ┆ 1613247 │
# │ 2008           ┆ 1720936 │
# │ 2009           ┆ 1537704 │
# │ 2010           ┆ 1689342 │
# │ 2011           ┆ 1778447 │
# └────────────────┴─────────┘

# %%
fig, ax = plt.subplots(figsize=(10, 5))

plt.plot(
    df_eda_qtd_alistados.select('vinculacao_ano'),
    df_eda_qtd_alistados.select('qtd'),
    marker='o'
)

ax.tick_params('x', rotation=90)
ax.set_xticks(anos)
ax.grid()
ax.set_ylabel('Quantidade')
ax.set_xlabel('Ano')

plt.tight_layout()
fig.savefig('pt/historico_qtd_alistados_por_ano.png', dpi=300, bbox_inches='tight')
plt.show()

# %%
fig, ax = plt.subplots(figsize=(10, 5))

plt.plot(
    df_eda_qtd_alistados.select('vinculacao_ano'),
    df_eda_qtd_alistados.select('qtd'),
    marker='o'
)

ax.tick_params('x', rotation=90)
ax.set_xticks(anos)
ax.grid()
ax.set_ylabel('Quantity')
ax.set_xlabel('Year')

plt.tight_layout()
fig.savefig('en/plot_number_men_yearly.png', dpi=300, bbox_inches='tight')
plt.show()

# %% [markdown]
# ### QUANTIDADE DE ALISTADOS POR ANO NAS GRANDE REGIÃO

# %%
grandes_regioes = {
    'Sul': ['RS', 'PR', 'SC'],
    'Nordeste': ['AL', 'PE', 'PB', 'CE', 'RN', 'MA', 'PI', 'SE', 'BA'],
    'Sudeste': ['SP', 'RJ', 'SP', 'ES'],
    'Centro-Oeste': ['DF', 'GO', 'MT', 'TO']
}

# %%
df = df_etl.with_columns(
    grande_regiao = (
        pl.when(pl.col('uf_nascimento').is_in(grandes_regioes['Sul'])).then(pl.lit('Sul'))
        .when(pl.col('uf_nascimento').is_in(grandes_regioes['Nordeste'])).then(pl.lit('Nordeste'))
        .when(pl.col('uf_nascimento').is_in(grandes_regioes['Sudeste'])).then(pl.lit('Sudeste'))
        .when(pl.col('uf_nascimento').is_in(grandes_regioes['Centro-Oeste'])).then(pl.lit('Centro-Oeste'))
        .otherwise(pl.lit('Norte'))
    )
)

# %%
df_eda_qtd_alistados_uf = df_etl.group_by(['vinculacao_ano', 'grande_regiao']).agg(
    qtd = pl.len()
).with_columns(
    qtd_pct = ((pl.col('qtd') / pl.col('qtd').sum().over('vinculacao_ano')) * 100).round(2)
).sort(['vinculacao_ano', 'grande_regiao'], descending=False)
# Out:
# ---------------------------------------------------------------------------
# ColumnNotFoundError                       Traceback (most recent call last)
# Cell In[77], line 1
# ----> 1 df_eda_qtd_alistados_uf = df_etl.group_by(['vinculacao_ano', 'grande_regiao']).agg(
#       2     qtd = pl.len()
#       3 ).with_columns(
#       4     qtd_pct = ((pl.col('qtd') / pl.col('qtd').sum().over('vinculacao_ano')) * 100).round(2)
#       5 ).sort(['vinculacao_ano', 'grande_regiao'], descending=False)
#
# File ~/miniconda3/envs/venv/lib/python3.12/site-packages/polars/dataframe/group_by.py:298, in GroupBy.agg(self, *aggs, **named_aggs)
#     195 """
#     196 Compute aggregations for each group of a group by operation.
#     197
#    (...)    291 └─────┴───────┴────────────────┘
#     292 """
#     293 from polars.lazyframe.opt_flags import QueryOptFlags
#     295 return (
#     296     self._lgb()
#     297     .agg(*aggs, **named_aggs)
# --> 298     .collect(optimizations=QueryOptFlags.none())
#     299 )
#
# File ~/miniconda3/envs/venv/lib/python3.12/site-packages/polars/_utils/deprecation.py:97, in deprecate_streaming_parameter.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#      93         kwargs["engine"] = "in-memory"
#      95     del kwargs["streaming"]
# ---> 97 return function(*args, **kwargs)
#
# File ~/miniconda3/envs/venv/lib/python3.12/site-packages/polars/lazyframe/opt_flags.py:324, in forward_old_opt_flags.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     321         optflags = cb(optflags, kwargs.pop(key))  # type: ignore[no-untyped-call,unused-ignore]
#     323 kwargs["optimizations"] = optflags
# --> 324 return function(*args, **kwargs)
#
# File ~/miniconda3/envs/venv/lib/python3.12/site-packages/polars/lazyframe/frame.py:2429, in LazyFrame.collect(self, type_coercion, predicate_pushdown, projection_pushdown, simplify_expression, slice_pushdown, comm_subplan_elim, comm_subexpr_elim, cluster_with_columns, collapse_joins, no_optimization, engine, background, optimizations, **_kwargs)
#    2427 # Only for testing purposes
#    2428 callback = _kwargs.get("post_opt_callback", callback)
# -> 2429 return wrap_df(ldf.collect(engine, callback))
#
# ColumnNotFoundError: unable to find column "grande_regiao"; valid columns: ["ano_nascimento", "uf_nascimento", "estado_civil", "sexo", "vinculacao_ano", "zona_residencial", "uf_residencia", "situacao", "nivel_educacional"]
#
# Resolved plan until failure:
#
# 	---> FAILED HERE RESOLVING 'sink' <---
# DF ["ano_nascimento", "uf_nascimento", "estado_civil", "sexo", ...]; PROJECT */9 COLUMNS

# %%
df_eda_qtd_alistados_uf.head()

# %%
fig, ax = plt.subplots(figsize=(10, 5))

marcadores = ['o', '>', 'd', 's', 'P', 'x']
cores = plt.get_cmap('Dark2').colors

for (grande_regiao, grupo), marcador, cor in zip(df_eda_qtd_alistados_uf.group_by('grande_regiao', maintain_order=True), marcadores, cores):
    ax.plot(
        grupo.select('vinculacao_ano'),
        grupo.select('qtd_pct'),
        label=grande_regiao,
        marker=marcador,
        color=cor
    )


ax.tick_params('x', rotation=90)
ax.set_xticks(anos)
ax.grid()
ax.set_ylabel('Quantidade (%)')
ax.set_xlabel('Ano')
ax.legend(loc='upper left', bbox_to_anchor=(1, 1))

plt.tight_layout()
fig.savefig('pt/historico_qtd_alistados_por_granderegiao.png', dpi=300, bbox_inches='tight')
plt.show()

# %%
renomeacao_grandes_regioes = {
    'Sul': 'South',
    'Norte': 'North',
    'Centro-Oeste': 'Midwest',
    'Sudeste': 'Southeast',
    'Nordeste': 'Northeast'
}

# %%
df_eda_qtd_alistados_uf = df_eda_qtd_alistados_uf.with_columns(
    pl.col('grande_regiao').replace(renomeacao_grandes_regioes)
)

# %%
fig, ax = plt.subplots(figsize=(10, 5))

marcadores = ['o', '>', 'd', 's', 'P', 'x']
cores = plt.get_cmap('Dark2').colors

for (grande_regiao, grupo), marcador, cor in zip(df_eda_qtd_alistados_uf.group_by('grande_regiao', maintain_order=True), marcadores, cores):
    ax.plot(
        grupo.select('vinculacao_ano'),
        grupo.select('qtd_pct'),
        label=grande_regiao,
        marker=marcador,
        color=cor
    )


ax.tick_params('x', rotation=90)
ax.set_xticks(anos)
ax.grid()
ax.set_ylabel('Percentage')
ax.set_xlabel('Year')
ax.legend(loc='upper left', bbox_to_anchor=(1, 1))

plt.tight_layout()
fig.savefig('en/plot_number_men_by_region.png', dpi=300, bbox_inches='tight')
plt.show()

# %% [markdown]
# ### NASCIMENTO POR ANO NAS GRANDE REGIÃO

# %% [markdown]
# ### RESIDENCIA POR ANO NAS GRANDE REGIÃO

# %% [markdown]
# ### QUANTOS RESIDEM NO MESMO LUGAR QUE NASCERAM

# %% [markdown]
# ## ANÁLISE BIVARIADAS

# %% [markdown]
# ## ANÁLISE MULTIVARIAVADA

# %% [markdown]
# # ML: CLUSTERIZAÇÃO
