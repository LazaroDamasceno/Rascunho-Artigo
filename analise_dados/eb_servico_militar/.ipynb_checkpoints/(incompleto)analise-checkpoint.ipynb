# %%
import polars as pl
import geopandas as gpd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
pl.Config.set_tbl_cols(-1)
pl.Config.set_tbl_rows(-1)
# Out:
# polars.config.Config

# %% [markdown]
# # ETL & DATA WANGLING

# %%
df = pl.scan_parquet('dados_parquet/*/*.parquet').collect()

# %%
df.head()
# Out:
# shape: (5, 15)
# ┌─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬────────┬───────┬───────┬───────┐
# │ ANO ┆ PES ┆ ALT ┆ MUN ┆ UF_ ┆ PAI ┆ EST ┆ SEX ┆ ESC ┆ VIN ┆ DIS ┆ ZONA_R ┆ MUN_R ┆ UF_RE ┆ PAIS_ │
# │ _NA ┆ O   ┆ URA ┆ _NA ┆ NAS ┆ S_N ┆ ADO ┆ O   ┆ OLA ┆ CUL ┆ PEN ┆ ESIDEN ┆ ESIDE ┆ SIDEN ┆ RESID │
# │ SCI ┆ --- ┆ --- ┆ SCI ┆ CIM ┆ ASC ┆ _CI ┆ --- ┆ RID ┆ ACA ┆ SA  ┆ CIAL   ┆ NCIA  ┆ CIA   ┆ ENCIA │
# │ MEN ┆ str ┆ str ┆ MEN ┆ ENT ┆ IME ┆ VIL ┆ str ┆ ADE ┆ O_A ┆ --- ┆ ---    ┆ ---   ┆ ---   ┆ ---   │
# │ TO  ┆     ┆     ┆ TO  ┆ O   ┆ NTO ┆ --- ┆     ┆ --- ┆ NO  ┆ str ┆ str    ┆ str   ┆ str   ┆ str   │
# │ --- ┆     ┆     ┆ --- ┆ --- ┆ --- ┆ str ┆     ┆ str ┆ --- ┆     ┆        ┆       ┆       ┆       │
# │ str ┆     ┆     ┆ str ┆ str ┆ str ┆     ┆     ┆     ┆ str ┆     ┆        ┆       ┆       ┆       │
# ╞═════╪═════╪═════╪═════╪═════╪═════╪═════╪═════╪═════╪═════╪═════╪════════╪═══════╪═══════╪═══════╡
# │ 198 ┆ 95  ┆ 181 ┆ DES ┆ SP  ┆ BRA ┆ Sol ┆ M   ┆ Ens ┆ 200 ┆ Sem ┆ Urbana ┆ PIRAS ┆ SP    ┆ BRASI │
# │ 9   ┆     ┆     ┆ CAL ┆     ┆ SIL ┆ tei ┆     ┆ ino ┆ 7   ┆ dis ┆        ┆ SUNUN ┆       ┆ L     │
# │     ┆     ┆     ┆ VAD ┆     ┆     ┆ ro  ┆     ┆ Méd ┆     ┆ pen ┆        ┆ GA    ┆       ┆       │
# │     ┆     ┆     ┆ O   ┆     ┆     ┆     ┆     ┆ io  ┆     ┆ sa  ┆        ┆       ┆       ┆       │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ Com ┆     ┆     ┆        ┆       ┆       ┆       │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ ple ┆     ┆     ┆        ┆       ┆       ┆       │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ to  ┆     ┆     ┆        ┆       ┆       ┆       │
# │ 198 ┆ 64  ┆ 173 ┆ CAT ┆ SP  ┆ BRA ┆ Cas ┆ M   ┆ Ens ┆ 200 ┆ Sem ┆ Urbana ┆ SAO   ┆ SP    ┆ BRASI │
# │ 9   ┆     ┆     ┆ AND ┆     ┆ SIL ┆ ado ┆     ┆ ino ┆ 7   ┆ dis ┆        ┆ PAULO ┆       ┆ L     │
# │     ┆     ┆     ┆ UVA ┆     ┆     ┆     ┆     ┆ Sup ┆     ┆ pen ┆        ┆       ┆       ┆       │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ eri ┆     ┆ sa  ┆        ┆       ┆       ┆       │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ or  ┆     ┆     ┆        ┆       ┆       ┆       │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ Com ┆     ┆     ┆        ┆       ┆       ┆       │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ ple ┆     ┆     ┆        ┆       ┆       ┆       │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ to  ┆     ┆     ┆        ┆       ┆       ┆       │
# │ 198 ┆ 82  ┆ 171 ┆ CAT ┆ SP  ┆ BRA ┆ Sol ┆ M   ┆ Ens ┆ 200 ┆ Sem ┆ Urbana ┆ CATAN ┆ SP    ┆ BRASI │
# │ 9   ┆     ┆     ┆ AND ┆     ┆ SIL ┆ tei ┆     ┆ ino ┆ 7   ┆ dis ┆        ┆ DUVA  ┆       ┆ L     │
# │     ┆     ┆     ┆ UVA ┆     ┆     ┆ ro  ┆     ┆ Méd ┆     ┆ pen ┆        ┆       ┆       ┆       │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ io  ┆     ┆ sa  ┆        ┆       ┆       ┆       │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ Com ┆     ┆     ┆        ┆       ┆       ┆       │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ ple ┆     ┆     ┆        ┆       ┆       ┆       │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ to  ┆     ┆     ┆        ┆       ┆       ┆       │
# │ 198 ┆ nul ┆ nul ┆ SAN ┆ SP  ┆ BRA ┆ Sol ┆ M   ┆ Ens ┆ 200 ┆ Sem ┆ Urbana ┆ PIRAJ ┆ SP    ┆ BRASI │
# │ 9   ┆ l   ┆ l   ┆ TO  ┆     ┆ SIL ┆ tei ┆     ┆ ino ┆ 7   ┆ dis ┆        ┆ UI    ┆       ┆ L     │
# │     ┆     ┆     ┆ AND ┆     ┆     ┆ ro  ┆     ┆ Méd ┆     ┆ pen ┆        ┆       ┆       ┆       │
# │     ┆     ┆     ┆ RE  ┆     ┆     ┆     ┆     ┆ io  ┆     ┆ sa  ┆        ┆       ┆       ┆       │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ Com ┆     ┆     ┆        ┆       ┆       ┆       │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ ple ┆     ┆     ┆        ┆       ┆       ┆       │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ to  ┆     ┆     ┆        ┆       ┆       ┆       │
# │ 198 ┆ nul ┆ nul ┆ PIR ┆ SP  ┆ BRA ┆ Sol ┆ M   ┆ 3ª  ┆ 200 ┆ Sem ┆ Urbana ┆ PIRAJ ┆ SP    ┆ BRASI │
# │ 9   ┆ l   ┆ l   ┆ AJU ┆     ┆ SIL ┆ tei ┆     ┆ Sér ┆ 7   ┆ dis ┆        ┆ UI    ┆       ┆ L     │
# │     ┆     ┆     ┆ I   ┆     ┆     ┆ ro  ┆     ┆ ie  ┆     ┆ pen ┆        ┆       ┆       ┆       │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ do  ┆     ┆ sa  ┆        ┆       ┆       ┆       │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ Ens ┆     ┆     ┆        ┆       ┆       ┆       │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ ino ┆     ┆     ┆        ┆       ┆       ┆       │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ Méd ┆     ┆     ┆        ┆       ┆       ┆       │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ io  ┆     ┆     ┆        ┆       ┆       ┆       │
# └─────┴─────┴─────┴─────┴─────┴─────┴─────┴─────┴─────┴─────┴─────┴────────┴───────┴───────┴───────┘

# %%
n_rows = df.shape[0]
n_rows
# Out:
# 26569408

# %%
for col in df.columns:
    qtd_nulos = df.select(
        pl.col(col).null_count()
    ).item()
    if qtd_nulos > 0:
        print(f'Coluna {col} tem {qtd_nulos} valores nulos.')
# Out:
# Coluna PESO tem 18598039 valores nulos.
# Coluna ALTURA tem 18588096 valores nulos.
# Coluna DISPENSA tem 474630 valores nulos.

# %%
df.group_by('VINCULACAO_ANO').agg(
    ((pl.col(['PESO', 'ALTURA', 'DISPENSA']).null_count() / pl.len()) * 100).round(2).name.suffix('_qtd_nulos')
)
# Out:
# shape: (18, 4)
# ┌────────────────┬────────────────┬──────────────────┬────────────────────┐
# │ VINCULACAO_ANO ┆ PESO_qtd_nulos ┆ ALTURA_qtd_nulos ┆ DISPENSA_qtd_nulos │
# │ ---            ┆ ---            ┆ ---              ┆ ---                │
# │ str            ┆ f64            ┆ f64              ┆ f64                │
# ╞════════════════╪════════════════╪══════════════════╪════════════════════╡
# │ 2023           ┆ 56.78          ┆ 56.78            ┆ 0.0                │
# │ 2013           ┆ 80.15          ┆ 80.15            ┆ 0.0                │
# │ 2010           ┆ 79.92          ┆ 79.92            ┆ 0.0                │
# │ 2017           ┆ 74.84          ┆ 74.82            ┆ 32.7               │
# │ 2009           ┆ 78.75          ┆ 78.74            ┆ 0.0                │
# │ 2011           ┆ 79.71          ┆ 79.71            ┆ 0.0                │
# │ 2008           ┆ 81.6           ┆ 81.47            ┆ 0.0                │
# │ 2020           ┆ 68.1           ┆ 68.12            ┆ 0.0                │
# │ 2014           ┆ 80.2           ┆ 80.19            ┆ 0.0                │
# │ 2015           ┆ 79.52          ┆ 79.52            ┆ 0.0                │
# │ 2018           ┆ 68.11          ┆ 68.11            ┆ 0.0                │
# │ 2012           ┆ 81.24          ┆ 81.24            ┆ 0.0                │
# │ 2022           ┆ 70.52          ┆ 70.52            ┆ 0.0                │
# │ 2024           ┆ 0.0            ┆ 0.0              ┆ 0.0                │
# │ 2021           ┆ 67.53          ┆ 67.53            ┆ 0.0                │
# │ 2019           ┆ 0.0            ┆ 0.0              ┆ 0.0                │
# │ 2016           ┆ 79.34          ┆ 79.35            ┆ 0.0                │
# │ 2007           ┆ 81.15          ┆ 80.7             ┆ 0.0                │
# └────────────────┴────────────────┴──────────────────┴────────────────────┘

# %%
df = df.drop(['PESO', 'ALTURA'])

# %%
df.select('DISPENSA').unique().to_series().to_list()
# Out:
# ['Sem dispensa', 'null', 'Com dispensa', None]

# %%
for col in df.columns:
    df = df.with_columns(
        pl.col(col).replace('null', None)
    )

# %%
for col in df.columns:
    qtd_nulos = df.select(
        pl.col(col).null_count()
    ).item()
    if qtd_nulos > 0:
        print(f'Coluna {col} tem {qtd_nulos} valores nulos.')
# Out:
# Coluna DISPENSA tem 474635 valores nulos.

# %%
df.select('DISPENSA').unique().to_series().to_list()
# Out:
# ['Com dispensa', 'Sem dispensa', None]

# %%
df = df.filter(
    pl.col('DISPENSA').is_not_null()
).with_columns(
    convocacao = pl.when(
        pl.col('DISPENSA') == 'Com dispensa'
    ).then(True).otherwise(False)
).drop('DISPENSA')

# %%
df.head()
# Out:
# shape: (5, 13)
# ┌─────┬─────┬─────┬────────┬────────┬──────┬───────┬───────┬───────┬───────┬───────┬───────┬───────┐
# │ ANO ┆ MUN ┆ UF_ ┆ PAIS_N ┆ ESTADO ┆ SEXO ┆ ESCOL ┆ VINCU ┆ ZONA_ ┆ MUN_R ┆ UF_RE ┆ PAIS_ ┆ convo │
# │ _NA ┆ _NA ┆ NAS ┆ ASCIME ┆ _CIVIL ┆ ---  ┆ ARIDA ┆ LACAO ┆ RESID ┆ ESIDE ┆ SIDEN ┆ RESID ┆ cacao │
# │ SCI ┆ SCI ┆ CIM ┆ NTO    ┆ ---    ┆ str  ┆ DE    ┆ _ANO  ┆ ENCIA ┆ NCIA  ┆ CIA   ┆ ENCIA ┆ ---   │
# │ MEN ┆ MEN ┆ ENT ┆ ---    ┆ str    ┆      ┆ ---   ┆ ---   ┆ L     ┆ ---   ┆ ---   ┆ ---   ┆ bool  │
# │ TO  ┆ TO  ┆ O   ┆ str    ┆        ┆      ┆ str   ┆ str   ┆ ---   ┆ str   ┆ str   ┆ str   ┆       │
# │ --- ┆ --- ┆ --- ┆        ┆        ┆      ┆       ┆       ┆ str   ┆       ┆       ┆       ┆       │
# │ str ┆ str ┆ str ┆        ┆        ┆      ┆       ┆       ┆       ┆       ┆       ┆       ┆       │
# ╞═════╪═════╪═════╪════════╪════════╪══════╪═══════╪═══════╪═══════╪═══════╪═══════╪═══════╪═══════╡
# │ 198 ┆ DES ┆ SP  ┆ BRASIL ┆ Soltei ┆ M    ┆ Ensin ┆ 2007  ┆ Urban ┆ PIRAS ┆ SP    ┆ BRASI ┆ false │
# │ 9   ┆ CAL ┆     ┆        ┆ ro     ┆      ┆ o     ┆       ┆ a     ┆ SUNUN ┆       ┆ L     ┆       │
# │     ┆ VAD ┆     ┆        ┆        ┆      ┆ Médio ┆       ┆       ┆ GA    ┆       ┆       ┆       │
# │     ┆ O   ┆     ┆        ┆        ┆      ┆ Compl ┆       ┆       ┆       ┆       ┆       ┆       │
# │     ┆     ┆     ┆        ┆        ┆      ┆ eto   ┆       ┆       ┆       ┆       ┆       ┆       │
# │ 198 ┆ CAT ┆ SP  ┆ BRASIL ┆ Casado ┆ M    ┆ Ensin ┆ 2007  ┆ Urban ┆ SAO   ┆ SP    ┆ BRASI ┆ false │
# │ 9   ┆ AND ┆     ┆        ┆        ┆      ┆ o Sup ┆       ┆ a     ┆ PAULO ┆       ┆ L     ┆       │
# │     ┆ UVA ┆     ┆        ┆        ┆      ┆ erior ┆       ┆       ┆       ┆       ┆       ┆       │
# │     ┆     ┆     ┆        ┆        ┆      ┆ Compl ┆       ┆       ┆       ┆       ┆       ┆       │
# │     ┆     ┆     ┆        ┆        ┆      ┆ eto   ┆       ┆       ┆       ┆       ┆       ┆       │
# │ 198 ┆ CAT ┆ SP  ┆ BRASIL ┆ Soltei ┆ M    ┆ Ensin ┆ 2007  ┆ Urban ┆ CATAN ┆ SP    ┆ BRASI ┆ false │
# │ 9   ┆ AND ┆     ┆        ┆ ro     ┆      ┆ o     ┆       ┆ a     ┆ DUVA  ┆       ┆ L     ┆       │
# │     ┆ UVA ┆     ┆        ┆        ┆      ┆ Médio ┆       ┆       ┆       ┆       ┆       ┆       │
# │     ┆     ┆     ┆        ┆        ┆      ┆ Compl ┆       ┆       ┆       ┆       ┆       ┆       │
# │     ┆     ┆     ┆        ┆        ┆      ┆ eto   ┆       ┆       ┆       ┆       ┆       ┆       │
# │ 198 ┆ SAN ┆ SP  ┆ BRASIL ┆ Soltei ┆ M    ┆ Ensin ┆ 2007  ┆ Urban ┆ PIRAJ ┆ SP    ┆ BRASI ┆ false │
# │ 9   ┆ TO  ┆     ┆        ┆ ro     ┆      ┆ o     ┆       ┆ a     ┆ UI    ┆       ┆ L     ┆       │
# │     ┆ AND ┆     ┆        ┆        ┆      ┆ Médio ┆       ┆       ┆       ┆       ┆       ┆       │
# │     ┆ RE  ┆     ┆        ┆        ┆      ┆ Compl ┆       ┆       ┆       ┆       ┆       ┆       │
# │     ┆     ┆     ┆        ┆        ┆      ┆ eto   ┆       ┆       ┆       ┆       ┆       ┆       │
# │ 198 ┆ PIR ┆ SP  ┆ BRASIL ┆ Soltei ┆ M    ┆ 3ª    ┆ 2007  ┆ Urban ┆ PIRAJ ┆ SP    ┆ BRASI ┆ false │
# │ 9   ┆ AJU ┆     ┆        ┆ ro     ┆      ┆ Série ┆       ┆ a     ┆ UI    ┆       ┆ L     ┆       │
# │     ┆ I   ┆     ┆        ┆        ┆      ┆ do    ┆       ┆       ┆       ┆       ┆       ┆       │
# │     ┆     ┆     ┆        ┆        ┆      ┆ Ensin ┆       ┆       ┆       ┆       ┆       ┆       │
# │     ┆     ┆     ┆        ┆        ┆      ┆ o     ┆       ┆       ┆       ┆       ┆       ┆       │
# │     ┆     ┆     ┆        ┆        ┆      ┆ Médio ┆       ┆       ┆       ┆       ┆       ┆       │
# └─────┴─────┴─────┴────────┴────────┴──────┴───────┴───────┴───────┴───────┴───────┴───────┴───────┘

# %%
df = df.with_columns(
    pl.col('ANO_NASCIMENTO').cast(pl.Int16),
    pl.col('UF_NASCIMENTO').cast(pl.Categorical),
    pl.col('VINCULACAO_ANO').cast(pl.Int16),
    pl.col('UF_RESIDENCIA').cast(pl.Categorical),
).drop(['MUN_NASCIMENTO', 'MUN_RESIDENCIA'])

# %%
n_rows = df.shape[0]
n_rows
# Out:
# 26094773

# %%
df.with_columns(
    nasceu_brasil = pl.col('PAIS_NASCIMENTO') == 'BRASIL',
    reside_brasil = pl.col('PAIS_RESIDENCIA') == 'BRASIL'
).select(
    pl.col(['nasceu_brasil', 'reside_brasil']).value_counts()
)
# Out:
# shape: (2, 2)
# ┌─────────────────┬─────────────────┐
# │ nasceu_brasil   ┆ reside_brasil   │
# │ ---             ┆ ---             │
# │ struct[2]       ┆ struct[2]       │
# ╞═════════════════╪═════════════════╡
# │ {false,76630}   ┆ {true,25979512} │
# │ {true,26018143} ┆ {false,115261}  │
# └─────────────────┴─────────────────┘

# %%
df = df.filter(
    pl.col('PAIS_NASCIMENTO') == 'BRASIL',
    pl.col('PAIS_RESIDENCIA') == 'BRASIL'
).drop(['PAIS_NASCIMENTO', 'PAIS_RESIDENCIA'])

# %%
df.head()
# Out:
# shape: (5, 9)
# ┌───────────┬───────────┬───────────┬──────┬───────────┬──────────┬──────────┬──────────┬──────────┐
# │ ANO_NASCI ┆ UF_NASCIM ┆ ESTADO_CI ┆ SEXO ┆ ESCOLARID ┆ VINCULAC ┆ ZONA_RES ┆ UF_RESID ┆ convocac │
# │ MENTO     ┆ ENTO      ┆ VIL       ┆ ---  ┆ ADE       ┆ AO_ANO   ┆ IDENCIAL ┆ ENCIA    ┆ ao       │
# │ ---       ┆ ---       ┆ ---       ┆ str  ┆ ---       ┆ ---      ┆ ---      ┆ ---      ┆ ---      │
# │ i16       ┆ cat       ┆ str       ┆      ┆ str       ┆ i16      ┆ str      ┆ cat      ┆ bool     │
# ╞═══════════╪═══════════╪═══════════╪══════╪═══════════╪══════════╪══════════╪══════════╪══════════╡
# │ 1989      ┆ SP        ┆ Solteiro  ┆ M    ┆ Ensino    ┆ 2007     ┆ Urbana   ┆ SP       ┆ false    │
# │           ┆           ┆           ┆      ┆ Médio     ┆          ┆          ┆          ┆          │
# │           ┆           ┆           ┆      ┆ Completo  ┆          ┆          ┆          ┆          │
# │ 1989      ┆ SP        ┆ Casado    ┆ M    ┆ Ensino    ┆ 2007     ┆ Urbana   ┆ SP       ┆ false    │
# │           ┆           ┆           ┆      ┆ Superior  ┆          ┆          ┆          ┆          │
# │           ┆           ┆           ┆      ┆ Completo  ┆          ┆          ┆          ┆          │
# │ 1989      ┆ SP        ┆ Solteiro  ┆ M    ┆ Ensino    ┆ 2007     ┆ Urbana   ┆ SP       ┆ false    │
# │           ┆           ┆           ┆      ┆ Médio     ┆          ┆          ┆          ┆          │
# │           ┆           ┆           ┆      ┆ Completo  ┆          ┆          ┆          ┆          │
# │ 1989      ┆ SP        ┆ Solteiro  ┆ M    ┆ Ensino    ┆ 2007     ┆ Urbana   ┆ SP       ┆ false    │
# │           ┆           ┆           ┆      ┆ Médio     ┆          ┆          ┆          ┆          │
# │           ┆           ┆           ┆      ┆ Completo  ┆          ┆          ┆          ┆          │
# │ 1989      ┆ SP        ┆ Solteiro  ┆ M    ┆ 3ª Série  ┆ 2007     ┆ Urbana   ┆ SP       ┆ false    │
# │           ┆           ┆           ┆      ┆ do Ensino ┆          ┆          ┆          ┆          │
# │           ┆           ┆           ┆      ┆ Médio     ┆          ┆          ┆          ┆          │
# └───────────┴───────────┴───────────┴──────┴───────────┴──────────┴──────────┴──────────┴──────────┘

# %%
print(df.select('ESTADO_CIVIL').unique().to_series().to_list())
# Out:
# ['Solteiro', 'Viúvo', 'Desquitado', 'Casado', 'Separado Judicialmente', 'Outros', 'Divorciado', 'ViÃºvo']

# %%
df = df.with_columns(
    pl.col('ESTADO_CIVIL').replace({
        'ViÃºvo': 'Viúvo',
        'Separado Judicialmente': 'Divorciado',
        'Desquitado': 'Divorciado',
    })
)

# %%
print(df.select('ESTADO_CIVIL').unique().to_series().to_list())
# Out:
# ['Casado', 'Viúvo', 'Outros', 'Divorciado', 'Solteiro']

# %%
df.select(
    pl.col('ESTADO_CIVIL').value_counts()
).unnest('ESTADO_CIVIL').group_by('ESTADO_CIVIL').agg(
    ((pl.col('count').sum() / n_rows) * 100).round(2)
)
# Out:
# shape: (5, 2)
# ┌──────────────┬───────┐
# │ ESTADO_CIVIL ┆ count │
# │ ---          ┆ ---   │
# │ str          ┆ f64   │
# ╞══════════════╪═══════╡
# │ Divorciado   ┆ 0.18  │
# │ Viúvo        ┆ 0.01  │
# │ Outros       ┆ 0.86  │
# │ Casado       ┆ 1.39  │
# │ Solteiro     ┆ 96.95 │
# └──────────────┴───────┘

# %%
df = df.filter(
    pl.col('ESTADO_CIVIL') == 'Solteiro'
).drop('ESTADO_CIVIL')

# %%
n_rows = df.shape[0]
n_rows
# Out:
# 25298928

# %%
df.head()
# Out:
# shape: (5, 8)
# ┌─────────────┬────────────┬──────┬────────────┬────────────┬────────────┬────────────┬────────────┐
# │ ANO_NASCIME ┆ UF_NASCIME ┆ SEXO ┆ ESCOLARIDA ┆ VINCULACAO ┆ ZONA_RESID ┆ UF_RESIDEN ┆ convocacao │
# │ NTO         ┆ NTO        ┆ ---  ┆ DE         ┆ _ANO       ┆ ENCIAL     ┆ CIA        ┆ ---        │
# │ ---         ┆ ---        ┆ str  ┆ ---        ┆ ---        ┆ ---        ┆ ---        ┆ bool       │
# │ i16         ┆ cat        ┆      ┆ str        ┆ i16        ┆ str        ┆ cat        ┆            │
# ╞═════════════╪════════════╪══════╪════════════╪════════════╪════════════╪════════════╪════════════╡
# │ 1989        ┆ SP         ┆ M    ┆ Ensino     ┆ 2007       ┆ Urbana     ┆ SP         ┆ false      │
# │             ┆            ┆      ┆ Médio      ┆            ┆            ┆            ┆            │
# │             ┆            ┆      ┆ Completo   ┆            ┆            ┆            ┆            │
# │ 1989        ┆ SP         ┆ M    ┆ Ensino     ┆ 2007       ┆ Urbana     ┆ SP         ┆ false      │
# │             ┆            ┆      ┆ Médio      ┆            ┆            ┆            ┆            │
# │             ┆            ┆      ┆ Completo   ┆            ┆            ┆            ┆            │
# │ 1989        ┆ SP         ┆ M    ┆ Ensino     ┆ 2007       ┆ Urbana     ┆ SP         ┆ false      │
# │             ┆            ┆      ┆ Médio      ┆            ┆            ┆            ┆            │
# │             ┆            ┆      ┆ Completo   ┆            ┆            ┆            ┆            │
# │ 1989        ┆ SP         ┆ M    ┆ 3ª Série   ┆ 2007       ┆ Urbana     ┆ SP         ┆ false      │
# │             ┆            ┆      ┆ do Ensino  ┆            ┆            ┆            ┆            │
# │             ┆            ┆      ┆ Médio      ┆            ┆            ┆            ┆            │
# │ 1989        ┆ SP         ┆ M    ┆ 2ª Série   ┆ 2007       ┆ Urbana     ┆ SP         ┆ false      │
# │             ┆            ┆      ┆ do Ensino  ┆            ┆            ┆            ┆            │
# │             ┆            ┆      ┆ Médio      ┆            ┆            ┆            ┆            │
# └─────────────┴────────────┴──────┴────────────┴────────────┴────────────┴────────────┴────────────┘

# %%
print(df.select('SEXO').unique().to_series().to_list())
# Out:
# ['M', 'F']

# %%
df.select(
    pl.col('SEXO').value_counts()
).unnest('SEXO').group_by('SEXO').agg(
    ((pl.col('count').sum() / n_rows) * 100).round(2)
)
# Out:
# shape: (2, 2)
# ┌──────┬───────┐
# │ SEXO ┆ count │
# │ ---  ┆ ---   │
# │ str  ┆ f64   │
# ╞══════╪═══════╡
# │ M    ┆ 99.95 │
# │ F    ┆ 0.05  │
# └──────┴───────┘

# %%
df = df.filter(
    pl.col('SEXO') != 'F'
).drop('SEXO')

# %%
n_rows = df.shape[0]
n_rows
# Out:
# 25287523

# %%
df.head()
# Out:
# shape: (5, 7)
# ┌──────────────┬──────────────┬─────────────┬─────────────┬─────────────┬─────────────┬────────────┐
# │ ANO_NASCIMEN ┆ UF_NASCIMENT ┆ ESCOLARIDAD ┆ VINCULACAO_ ┆ ZONA_RESIDE ┆ UF_RESIDENC ┆ convocacao │
# │ TO           ┆ O            ┆ E           ┆ ANO         ┆ NCIAL       ┆ IA          ┆ ---        │
# │ ---          ┆ ---          ┆ ---         ┆ ---         ┆ ---         ┆ ---         ┆ bool       │
# │ i16          ┆ cat          ┆ str         ┆ i16         ┆ str         ┆ cat         ┆            │
# ╞══════════════╪══════════════╪═════════════╪═════════════╪═════════════╪═════════════╪════════════╡
# │ 1989         ┆ SP           ┆ Ensino      ┆ 2007        ┆ Urbana      ┆ SP          ┆ false      │
# │              ┆              ┆ Médio       ┆             ┆             ┆             ┆            │
# │              ┆              ┆ Completo    ┆             ┆             ┆             ┆            │
# │ 1989         ┆ SP           ┆ Ensino      ┆ 2007        ┆ Urbana      ┆ SP          ┆ false      │
# │              ┆              ┆ Médio       ┆             ┆             ┆             ┆            │
# │              ┆              ┆ Completo    ┆             ┆             ┆             ┆            │
# │ 1989         ┆ SP           ┆ Ensino      ┆ 2007        ┆ Urbana      ┆ SP          ┆ false      │
# │              ┆              ┆ Médio       ┆             ┆             ┆             ┆            │
# │              ┆              ┆ Completo    ┆             ┆             ┆             ┆            │
# │ 1989         ┆ SP           ┆ 3ª Série do ┆ 2007        ┆ Urbana      ┆ SP          ┆ false      │
# │              ┆              ┆ Ensino      ┆             ┆             ┆             ┆            │
# │              ┆              ┆ Médio       ┆             ┆             ┆             ┆            │
# │ 1989         ┆ SP           ┆ 2ª Série do ┆ 2007        ┆ Urbana      ┆ SP          ┆ false      │
# │              ┆              ┆ Ensino      ┆             ┆             ┆             ┆            │
# │              ┆              ┆ Médio       ┆             ┆             ┆             ┆            │
# └──────────────┴──────────────┴─────────────┴─────────────┴─────────────┴─────────────┴────────────┘

# %%
print(df.select('ZONA_RESIDENCIAL').unique().to_series().to_list())
# Out:
# ['Rural', 'Urbana']

# %%
df.select(
    pl.col('ZONA_RESIDENCIAL').value_counts()
).unnest('ZONA_RESIDENCIAL').group_by('ZONA_RESIDENCIAL').agg(
    ((pl.col('count').sum() / n_rows) * 100).round(2)
)
# Out:
# shape: (2, 2)
# ┌──────────────────┬───────┐
# │ ZONA_RESIDENCIAL ┆ count │
# │ ---              ┆ ---   │
# │ str              ┆ f64   │
# ╞══════════════════╪═══════╡
# │ Urbana           ┆ 87.89 │
# │ Rural            ┆ 12.11 │
# └──────────────────┴───────┘

# %%
df = df.with_columns(
    pl.col('ZONA_RESIDENCIAL').cast(pl.Categorical)
)

# %%
df.head()
# Out:
# shape: (5, 7)
# ┌──────────────┬──────────────┬─────────────┬─────────────┬─────────────┬─────────────┬────────────┐
# │ ANO_NASCIMEN ┆ UF_NASCIMENT ┆ ESCOLARIDAD ┆ VINCULACAO_ ┆ ZONA_RESIDE ┆ UF_RESIDENC ┆ convocacao │
# │ TO           ┆ O            ┆ E           ┆ ANO         ┆ NCIAL       ┆ IA          ┆ ---        │
# │ ---          ┆ ---          ┆ ---         ┆ ---         ┆ ---         ┆ ---         ┆ bool       │
# │ i16          ┆ cat          ┆ str         ┆ i16         ┆ cat         ┆ cat         ┆            │
# ╞══════════════╪══════════════╪═════════════╪═════════════╪═════════════╪═════════════╪════════════╡
# │ 1989         ┆ SP           ┆ Ensino      ┆ 2007        ┆ Urbana      ┆ SP          ┆ false      │
# │              ┆              ┆ Médio       ┆             ┆             ┆             ┆            │
# │              ┆              ┆ Completo    ┆             ┆             ┆             ┆            │
# │ 1989         ┆ SP           ┆ Ensino      ┆ 2007        ┆ Urbana      ┆ SP          ┆ false      │
# │              ┆              ┆ Médio       ┆             ┆             ┆             ┆            │
# │              ┆              ┆ Completo    ┆             ┆             ┆             ┆            │
# │ 1989         ┆ SP           ┆ Ensino      ┆ 2007        ┆ Urbana      ┆ SP          ┆ false      │
# │              ┆              ┆ Médio       ┆             ┆             ┆             ┆            │
# │              ┆              ┆ Completo    ┆             ┆             ┆             ┆            │
# │ 1989         ┆ SP           ┆ 3ª Série do ┆ 2007        ┆ Urbana      ┆ SP          ┆ false      │
# │              ┆              ┆ Ensino      ┆             ┆             ┆             ┆            │
# │              ┆              ┆ Médio       ┆             ┆             ┆             ┆            │
# │ 1989         ┆ SP           ┆ 2ª Série do ┆ 2007        ┆ Urbana      ┆ SP          ┆ false      │
# │              ┆              ┆ Ensino      ┆             ┆             ┆             ┆            │
# │              ┆              ┆ Médio       ┆             ┆             ┆             ┆            │
# └──────────────┴──────────────┴─────────────┴─────────────┴─────────────┴─────────────┴────────────┘

# %%
print(df.select('ESCOLARIDADE').unique().to_series().to_list())
# Out:
# ['7ª Série do Ensino Fundamental', '6° Ano - Ensino Fundamental', 'PÃ³s-Doutorado', '2° Semestre - Ensino Superior', '8° Ano - Ensino Fundamental', '1ª Série do Ensino Médio', '1° Semestre do Ensino Superior', '5° Semestre do Ensino Superior', '3Â° Semestre - Ensino Superior', '2Â° Ano - Ensino Fundamental', '2° Ano - Ensino Médio', '6° Semestre - Ensino Superior', '3° Ano - Ensino Fundamental', '7Â° Ano - Ensino Fundamental', '9Â° Semestre - Ensino Superior', '1° Semestre - Ensino Superior', '5ª Série do Ensino Fundamental', 'Pós-Doutorado', '1° Ano - Ensino Médio', '2Â° Ano - Ensino MÃ©dio', '1° Ano - Ensino Fundamental', 'Ensino MÃ©dio Completo', '8Â° Semestre - Ensino Superior', '5° Ano - Ensino Fundamental', '8Â° Ano - Ensino Fundamental', '10° Semestre - Ensino Superior', 'PÃ³s-GraduaÃ§â\x95\x9eo', '4° Ano - Ensino Médio (Profissionalizante)', '4Â° Ano - Ensino Fundamental', '9° Semestre do Ensino Superior', '3Â° Ano - Ensino MÃ©dio', '6Â° Ano - Ensino Fundamental', 'Ensino Superior Completo', '9Â° Ano - Ensino Fundamental', '1Â° Ano - Ensino Fundamental', '3ª Série do Ensino Fundamental', 'Ensino Fundamental Completo', '5Â° Ano - Ensino Fundamental', '2° Ano - Ensino Fundamental', '4Â° Ano - Ensino MÃ©dio (Profissionalizante)', '1ª Série do Ensino Fundamental', '7Â° Semestre - Ensino Superior', '2° Semestre do Ensino Superior', 'PÃ³s-GraduaÃ§Ã£o', '3Â° Ano - Ensino Fundamental', '9° Semestre - Ensino Superior', '6ª Série do Ensino Fundamental', '6Â° Semestre - Ensino Superior', '4Â° Semestre - Ensino Superior', '9° Ano - Ensino Fundamental', '5° Semestre - Ensino Superior', '1Â° Semestre - Ensino Superior', '4ª Série do Ensino Médio', '1Â° Ano - Ensino MÃ©dio', '2Â° Semestre - Ensino Superior', 'Analfabeto', '7° Semestre do Ensino Superior', 'Doutorado', '3° Ano - Ensino Médio', '9ª Série do Ensino Fundamental', '3ª Série do Ensino Médio', '4° Semestre do Ensino Superior', '7° Ano - Ensino Fundamental', 'Pós-Graduação', '10° Semestre do Ensino Superior', '8° Semestre - Ensino Superior', '8ª Série do Ensino Fundamental', '10Â° Semestre - Ensino Superior', '4° Semestre - Ensino Superior', '6° Semestre do Ensino Superior', 'Ensino Médio Completo', 'Mestrado', '3° Semestre do Ensino Superior', '4ª Série do Ensino Fundamental', '5Â° Semestre - Ensino Superior', '4° Ano - Ensino Fundamental', '7° Semestre - Ensino Superior', '8° Semestre do Ensino Superior', '2ª Série do Ensino Médio', '2ª Série do Ensino Fundamental', 'Alfabetizado', '3° Semestre - Ensino Superior']

# %%
df = df.with_columns(
    pl.col('ESCOLARIDADE').str.replace_many({
        'Â°': '°',
        'Ã©': 'é',        
        'Ã³s': 'ó',
        'Ã§Ã£o': 'ção',
        'Ã§â\x95\x9eo': 'ção'
    }, ascii_case_insensitive=True)
)

# %%
print(df.select('ESCOLARIDADE').unique().to_series().to_list())
# Out:
# ['8° Semestre - Ensino Superior', '7° Semestre - Ensino Superior', 'Pós-Graduação', '9° Semestre - Ensino Superior', '6° Semestre do Ensino Superior', '4° Semestre - Ensino Superior', '4° Ano - Ensino Médio (Profissionalizante)', 'Alfabetizado', '7° Ano - Ensino Fundamental', 'Mestrado', '2° Ano - Ensino Fundamental', 'Pó-Doutorado', '3° Ano - Ensino Médio', '4ª Série do Ensino Médio', '3° Semestre - Ensino Superior', '4° Semestre do Ensino Superior', '6° Ano - Ensino Fundamental', '7ª Série do Ensino Fundamental', '10° Semestre - Ensino Superior', '1ª Série do Ensino Fundamental', '6ª Série do Ensino Fundamental', '3° Semestre do Ensino Superior', 'Ensino Fundamental Completo', 'Pó-Graduação', 'Doutorado', '5° Ano - Ensino Fundamental', '8° Semestre do Ensino Superior', '5ª Série do Ensino Fundamental', '8ª Série do Ensino Fundamental', '8° Ano - Ensino Fundamental', '9° Ano - Ensino Fundamental', '3ª Série do Ensino Fundamental', 'Ensino Superior Completo', 'Pós-Doutorado', '9° Semestre do Ensino Superior', '2° Ano - Ensino Médio', '3ª Série do Ensino Médio', '3° Ano - Ensino Fundamental', '1° Semestre - Ensino Superior', '4ª Série do Ensino Fundamental', '4° Ano - Ensino Fundamental', '2ª Série do Ensino Fundamental', 'Analfabeto', '1° Ano - Ensino Médio', '7° Semestre do Ensino Superior', '5° Semestre - Ensino Superior', '6° Semestre - Ensino Superior', '9ª Série do Ensino Fundamental', '1ª Série do Ensino Médio', '5° Semestre do Ensino Superior', '2ª Série do Ensino Médio', 'Ensino Médio Completo', '10° Semestre do Ensino Superior', '1° Ano - Ensino Fundamental', '2° Semestre do Ensino Superior', '1° Semestre do Ensino Superior', '2° Semestre - Ensino Superior']

# %%
ensino_fundamental = df.select('ESCOLARIDADE').filter(
    pl.col('ESCOLARIDADE').str.contains('Ensino Fundamental')
).unique().to_series().to_list()

# %%
ensino_medio = df.select('ESCOLARIDADE').filter(
    pl.col('ESCOLARIDADE').str.contains('Ensino Médio')
).unique().to_series().to_list()

# %%
graduacao = df.select('ESCOLARIDADE').filter(
    pl.col('ESCOLARIDADE').str.contains('Ensino Superior')
).unique().to_series().to_list()

# %%
ordem_escolaridade = [
    'Analfabeto',
    'Alfabetizado',
    'Ensino Fundamental',
    'Ensino Médio',
    'Graduação',
    'Pós-Graduação'
]

# %%
df = df.with_columns(
    nivel_educacional = pl.when(pl.col('ESCOLARIDADE') == 'Analfabeto')
        .then(pl.lit('Analfabeto'))
        .when(pl.col('ESCOLARIDADE') == 'Alfabetizado')
        .then(pl.lit('Alfabetizado'))
        .when(pl.col('ESCOLARIDADE').is_in(ensino_fundamental))
        .then(pl.lit('Ensino Fundamental'))
        .when(pl.col('ESCOLARIDADE').is_in(ensino_medio))
        .then(pl.lit('Ensino Médio'))
        .when(pl.col('ESCOLARIDADE').is_in(graduacao))
        .then(pl.lit('Graduação'))
        .otherwise(pl.lit('Pós-Graduação'))
).with_columns(
    pl.col('nivel_educacional').cast(pl.Enum(ordem_escolaridade))
).drop('ESCOLARIDADE')

# %%
cols_maiusculas = df.columns
cols_minusculas = [col.lower() for col in df.columns]
cols_transformadas = dict(zip(cols_maiusculas, cols_minusculas))

# %%
df = df.rename(cols_transformadas)

# %% [markdown]
# df.head()

# %%
df.shape
# Out:
# (25287523, 7)

# %% [markdown]
# # EDA

# %%
df.head()
# Out:
# shape: (5, 7)
# ┌──────────────┬──────────────┬─────────────┬─────────────┬─────────────┬────────────┬─────────────┐
# │ ano_nascimen ┆ uf_nasciment ┆ vinculacao_ ┆ zona_reside ┆ uf_residenc ┆ convocacao ┆ nivel_educa │
# │ to           ┆ o            ┆ ano         ┆ ncial       ┆ ia          ┆ ---        ┆ cional      │
# │ ---          ┆ ---          ┆ ---         ┆ ---         ┆ ---         ┆ bool       ┆ ---         │
# │ i16          ┆ cat          ┆ i16         ┆ cat         ┆ cat         ┆            ┆ enum        │
# ╞══════════════╪══════════════╪═════════════╪═════════════╪═════════════╪════════════╪═════════════╡
# │ 1989         ┆ SP           ┆ 2007        ┆ Urbana      ┆ SP          ┆ false      ┆ Ensino      │
# │              ┆              ┆             ┆             ┆             ┆            ┆ Médio       │
# │ 1989         ┆ SP           ┆ 2007        ┆ Urbana      ┆ SP          ┆ false      ┆ Ensino      │
# │              ┆              ┆             ┆             ┆             ┆            ┆ Médio       │
# │ 1989         ┆ SP           ┆ 2007        ┆ Urbana      ┆ SP          ┆ false      ┆ Ensino      │
# │              ┆              ┆             ┆             ┆             ┆            ┆ Médio       │
# │ 1989         ┆ SP           ┆ 2007        ┆ Urbana      ┆ SP          ┆ false      ┆ Ensino      │
# │              ┆              ┆             ┆             ┆             ┆            ┆ Médio       │
# │ 1989         ┆ SP           ┆ 2007        ┆ Urbana      ┆ SP          ┆ false      ┆ Ensino      │
# │              ┆              ┆             ┆             ┆             ┆            ┆ Médio       │
# └──────────────┴──────────────┴─────────────┴─────────────┴─────────────┴────────────┴─────────────┘

# %%
anos = sorted(df.select('vinculacao_ano').unique().to_series().to_list())

# %%
df_edu = df.group_by(['vinculacao_ano', 'nivel_educacional']).agg(
    qtd = pl.len()
).with_columns(
    qtd_pct = ((pl.col('qtd') / pl.col('qtd').sum().over('vinculacao_ano')) * 100).round(2)
).sort(['vinculacao_ano', 'nivel_educacional'], descending=False)

# %%
df_edu.head(10)
# Out:
# shape: (10, 4)
# ┌────────────────┬────────────────────┬────────┬─────────┐
# │ vinculacao_ano ┆ nivel_educacional  ┆ qtd    ┆ qtd_pct │
# │ ---            ┆ ---                ┆ ---    ┆ ---     │
# │ i16            ┆ enum               ┆ u32    ┆ f64     │
# ╞════════════════╪════════════════════╪════════╪═════════╡
# │ 2007           ┆ Analfabeto         ┆ 8546   ┆ 0.54    │
# │ 2007           ┆ Alfabetizado       ┆ 23120  ┆ 1.47    │
# │ 2007           ┆ Ensino Fundamental ┆ 530906 ┆ 33.8    │
# │ 2007           ┆ Ensino Médio       ┆ 937126 ┆ 59.66   │
# │ 2007           ┆ Graduação          ┆ 70915  ┆ 4.51    │
# │ 2007           ┆ Pós-Graduação      ┆ 168    ┆ 0.01    │
# │ 2008           ┆ Analfabeto         ┆ 18338  ┆ 1.1     │
# │ 2008           ┆ Alfabetizado       ┆ 35430  ┆ 2.12    │
# │ 2008           ┆ Ensino Fundamental ┆ 619310 ┆ 37.05   │
# │ 2008           ┆ Ensino Médio       ┆ 928640 ┆ 55.56   │
# └────────────────┴────────────────────┴────────┴─────────┘

# %%
fig, ax = plt.subplots(figsize=(10, 5))

marcadores = ['o', '>', 'd', 's', 'P', 'x']
dark2 = plt.get_cmap('Dark2').colors

for (nivel_educacional, grupo), marcador, cor in zip(df_edu.group_by('nivel_educacional', maintain_order=True), marcadores, dark2):
    ax.plot(
        grupo.select('vinculacao_ano'),
        grupo.select('qtd'),
        label=nivel_educacional,
        marker=marcador,
        color=cor
    )

ax.tick_params('x', rotation=90)
ax.set_xticks(anos)
ax.legend(loc='upper left', bbox_to_anchor=(1, 1))
ax.grid()
ax.set_ylabel('Quantidade')
ax.set_xlabel('Ano')

plt.tight_layout()
plt.show()

# %%
fig, ax = plt.subplots(figsize=(10, 5))

marcadores = ['o', '>', 'd', 's', 'P', 'x']
dark2 = plt.get_cmap('Dark2').colors

for (nivel_educacional, grupo), marcador, cor in zip(df_edu.group_by('nivel_educacional', maintain_order=True), marcadores, dark2):
    ax.plot(
        grupo.select('vinculacao_ano'),
        grupo.select('qtd_pct'),
        label=nivel_educacional,
        marker=marcador,
        color=cor
    )

ax.tick_params('x', rotation=90)
ax.set_xticks(anos)
ax.legend(loc='upper left', bbox_to_anchor=(1, 1))
ax.grid()
ax.set_ylim(0, 100)
ax.set_ylabel('Quantidade (%)')
ax.set_xlabel('Ano')

plt.tight_layout()
plt.show()

# %% [markdown]
# # ML: CLUSTERIZAÇÃO
