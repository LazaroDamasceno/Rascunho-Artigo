# %%
import polars as pl

# %%
pl.Config.set_tbl_rows(-1)
pl.Config.set_tbl_cols(-1)
# Out:
# polars.config.Config

# %%
df = pl.read_parquet('dados_parquet/*.parquet')

# %%
df.head()
# Out:
# shape: (5, 15)
# ┌─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬────────┬───────┬───────┬───────┐
# │ ANO ┆ PES ┆ ALT ┆ MUN ┆ UF_ ┆ PAI ┆ EST ┆ SEX ┆ ESC ┆ VIN ┆ DIS ┆ ZONA_R ┆ MUN_R ┆ UF_RE ┆ PAIS_ │
# │ _NA ┆ O   ┆ URA ┆ _NA ┆ NAS ┆ S_N ┆ ADO ┆ O   ┆ OLA ┆ CUL ┆ PEN ┆ ESIDEN ┆ ESIDE ┆ SIDEN ┆ RESID │
# │ SCI ┆ --- ┆ --- ┆ SCI ┆ CIM ┆ ASC ┆ _CI ┆ --- ┆ RID ┆ ACA ┆ SA  ┆ CIAL   ┆ NCIA  ┆ CIA   ┆ ENCIA │
# │ MEN ┆ str ┆ str ┆ MEN ┆ ENT ┆ IME ┆ VIL ┆ str ┆ ADE ┆ O_A ┆ --- ┆ ---    ┆ ---   ┆ ---   ┆ ---   │
# │ TO  ┆     ┆     ┆ TO  ┆ O   ┆ NTO ┆ --- ┆     ┆ --- ┆ NO  ┆ str ┆ str    ┆ str   ┆ str   ┆ str   │
# │ --- ┆     ┆     ┆ --- ┆ --- ┆ --- ┆ str ┆     ┆ str ┆ --- ┆     ┆        ┆       ┆       ┆       │
# │ str ┆     ┆     ┆ str ┆ str ┆ str ┆     ┆     ┆     ┆ str ┆     ┆        ┆       ┆       ┆       │
# ╞═════╪═════╪═════╪═════╪═════╪═════╪═════╪═════╪═════╪═════╪═════╪════════╪═══════╪═══════╪═══════╡
# ...

# %%
df.select('ESCOLARIDADE').unique()
# Out:
# shape: (84, 1)
# ┌─────────────────────────────────┐
# │ ESCOLARIDADE                    │
# │ ---                             │
# │ str                             │
# ╞═════════════════════════════════╡
# │ 1ª Série do Ensino Médio        │
# │ 7° Semestre do Ensino Superior  │
# │ 7° Ano - Ensino Fundamental     │
# │ 2ª Série do Ensino Médio        │
# │ 1Â° Semestre - Ensino Superior  │
# │ 3° Semestre - Ensino Superior   │
# │ 5° Semestre do Ensino Superior  │
# │ 4ª Série do Ensino Médio        │
# │ 4° Ano - Ensino Fundamental     │
# │ 3ª Série do Ensino Fundamental  │
# │ 9° Semestre - Ensino Superior   │
# │ 9Â° Ano - Ensino Fundamental    │
# │ 2° Semestre do Ensino Superior  │
# │ 2Â° Ano - Ensino Fundamental    │
# │ 3Â° Ano - Ensino MÃ©dio         │
# │ 2Â° Ano - Ensino MÃ©dio         │
# │ 2024                            │
# │ 6° Ano - Ensino Fundamental     │
# │ Mestrado                        │
# │ 4° Semestre - Ensino Superior   │
# ...
