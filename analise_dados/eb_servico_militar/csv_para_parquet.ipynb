# %%
from pyspark.sql import SparkSession
from pyspark.sql import functions as F

# %%
spark = SparkSession.builder.appName("Spark DataFrames").getOrCreate()

# %%
path = '/Volumes/workspace/default/dados_csv/'

# %%
df = spark.read.csv(
    path,
    encoding='utf-8',
    header=True,
    inferSchema=True           
)

# %%
df.columns
# Out:
# ['ANO_NASCIMENTO',
#  'PESO',
#  'ALTURA',
#  'CABECA',
#  'CALCADO',
#  'CINTURA',
#  'RELIGIAO',
#  'MUN_NASCIMENTO',
#  'UF_NASCIMENTO',
#  'PAIS_NASCIMENTO',
#  'ESTADO_CIVIL',
#  'SEXO',
#  'ESCOLARIDADE',
#  'VINCULACAO_ANO',
#  'DISPENSA',
#  'ZONA_RESIDENCIAL',
#  'MUN_RESIDENCIA',
#  'UF_RESIDENCIA',
#  'PAIS_RESIDENCIA',
#  'JSM',
#  'MUN_JSM',
#  'UF_JSM']

# %%
len(df.columns)
# Out:
# 22

# %%
df = df.drop(
    'CABECA',
    'CINTURA',
    'JSM',
    'MUN_JSM',
    'UF_JSM',
    'RELIGIAO',
    'CALCADO'
)

# %%
df.columns
# Out:
# ['ANO_NASCIMENTO',
#  'PESO',
#  'ALTURA',
#  'MUN_NASCIMENTO',
#  'UF_NASCIMENTO',
#  'PAIS_NASCIMENTO',
#  'ESTADO_CIVIL',
#  'SEXO',
#  'ESCOLARIDADE',
#  'VINCULACAO_ANO',
#  'DISPENSA',
#  'ZONA_RESIDENCIAL',
#  'MUN_RESIDENCIA',
#  'UF_RESIDENCIA',
#  'PAIS_RESIDENCIA']

# %%
len(df.columns)
# Out:
# 15

# %%
df.write.parquet(
    '/Volumes/workspace/default/dados_parquet/',
    mode='overwrite'
)
