# %%
import polars as pl

# %%
df_2007_2021 = pl.scan_parquet('dados_parquet/2007_2021/*.parquet').collect()

# %%
df_2022_2024 = pl.scan_parquet('dados_parquet/2022_2024/*.parquet').collect()

# %%
df_2022_2024.select(
    pl.col('VINCULACAO_ANO')
).unique().to_series().to_list()
# Out:
# ['2024', '2023', '2022']
